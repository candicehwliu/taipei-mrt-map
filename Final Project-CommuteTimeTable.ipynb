# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import warnings
warnings.filterwarnings('ignore')
import json

# %%
# purpose: open and read txt file function
def open_read(txt_file):
    # reading the txt data by using JSON
    with open(txt_file, encoding='utf-8') as file:
        json_data = json.load(file)
        # converting json dataset from dictionary to dataframe
        df = pd.DataFrame(json_data)
    return df

# %%
traveltime_df = open_read('traveltime.txt')

# %%
# create dictionarys - {key=RouteID : value=TravelTimes}
route_traveltimes_dict = {}
for row_index, route_id in enumerate(traveltime_df['RouteID']):
    route_traveltimes_dict[route_id] = pd.json_normalize(traveltime_df['TravelTimes'][row_index])

# %%
# purpose: revise linecolor label and fill the whole name
def extract_color(color_ID):
    if color_ID[0:2] == 'BR':
        return 'brown'
    elif color_ID[0:1] == 'R':
        return 'red'
    elif color_ID[0:1] == 'Y':
        return 'yellow'
    elif color_ID[0:1] == 'B' or color_ID[0:2] == 'BL':
        return 'blue'
    elif color_ID[0:1] == 'O':
        return 'orange'
    elif color_ID[0:1] == 'G':
        return 'green'

# %%
#  purpose: create timetables with calculating all timevalues
def get_route_timetable(traveltimes_df):
    # add a new column to calculate commute time in each station
    traveltimes_df['TakeTime'] = traveltimes_df['RunTime'] + traveltimes_df['StopTime']
    # add a new column to calculate commute time between two stations
    traveltimes_df['AccTime'] = traveltimes_df['TakeTime'].cumsum()
    # add a new column to classify stations by their linescolors
    traveltimes_df['Line_Color'] = traveltimes_df['FromStationID'].apply(extract_color)
    
    times_df = traveltimes_df.rename(columns={'FromStationName.Zh_tw':'FromStationName', 'ToStationName.Zh_tw':'ToStationName'})
    return times_df

# purpose: create a pivot table - the index and column frame by all station names
def get_route_stationtable(traveltimes_df):
    # if totalstation=n, FromStationName has n-1 station names(coz end station name in ToStationName)
    indexes = np.append(traveltimes_df['FromStationName.Zh_tw'].values, traveltimes_df['ToStationName.Zh_tw'].iloc[-1])
    stationframe_df = pd.DataFrame(index=indexes, columns=indexes)
    return stationframe_df

# purpose: fill all timevalues in the station framtable and search total commute time between two stations
def fill_timevalue(traveltimes_df, stationframe_df):
    
    stop_time = np.array(traveltimes_df['StopTime'])
    # StopTime in the last station is 0
    stop_time = np.append(stop_time, 0)
    take_time = np.array(traveltimes_df['TakeTime'])

    for row_index in range(len(stationframe_df)):
        for column_index in range(len(stationframe_df)):
            if row_index == column_index:
                stationframe_df.iloc[row_index][column_index] = stop_time[row_index]
            elif row_index < column_index:                
                stationframe_df.iloc[row_index][column_index] = take_time[row_index:column_index].sum()
            elif row_index > column_index:
                stationframe_df.iloc[row_index][column_index] = take_time[column_index:row_index].sum()
            else:
                continue
                
    schedule_df = stationframe_df
    return schedule_df

# %%
# create dictionarys - {key:routecolor: {key=stationname0: {key=stationnames: value=commutetimes between other stations}}
commutetimes_dict = {}    
for row_index, route_id in enumerate(traveltime_df['RouteID']):
    commutetimes_dict[route_id] = fill_timevalue(get_route_timetable(route_traveltimes_dict[route_id]), get_route_stationtable(route_traveltimes_dict[route_id])).to_dict()

# print(commutetimes_dict)
commutetimes_dict["O-2"]
# Out:
# {'蘆洲': {'蘆洲': 0,
#   '三民高中': 111,
#   '徐匯中學': 228,
#   '三和國中': 335,
#   '三重國小': 467,
#   '大橋頭': 643,
#   '民權西路': 741,
#   '中山國小': 846,
#   '行天宮': 972,
#   '松江南京': 1080,
#   '忠孝新生': 1212,
#   '東門': 1386,
#   '古亭': 1627,
#   '頂溪': 1847,
#   '永安市場': 1979,
#   '景安': 2098,
#   '南勢角': 2223},
#  '三民高中': {'蘆洲': 111,
#   '三民高中': 25,
#   '徐匯中學': 117,
#   '三和國中': 224,
#   '三重國小': 356,
#   '大橋頭': 532,
#   '民權西路': 630,
#   '中山國小': 735,
#   '行天宮': 861,
#   '松江南京': 969,
#   '忠孝新生': 1101,
#   '東門': 1275,
#   '古亭': 1516,
#   '頂溪': 1736,
#   '永安市場': 1868,
#   '景安': 1987,
#   '南勢角': 2112},
#  '徐匯中學': {'蘆洲': 228,
#   '三民高中': 117,
#   '徐匯中學': 25,
#   '三和國中': 107,
#   '三重國小': 239,
#   '大橋頭': 415,
#   '民權西路': 513,
#   '中山國小': 618,
#   '行天宮': 744,
#   '松江南京': 852,
#   '忠孝新生': 984,
#   '東門': 1158,
#   '古亭': 1399,
#   '頂溪': 1619,
#   '永安市場': 1751,
#   '景安': 1870,
#   '南勢角': 1995},
#  '三和國中': {'蘆洲': 335,
#   '三民高中': 224,
#   '徐匯中學': 107,
#   '三和國中': 25,
#   '三重國小': 132,
#   '大橋頭': 308,
#   '民權西路': 406,
#   '中山國小': 511,
#   '行天宮': 637,
#   '松江南京': 745,
#   '忠孝新生': 877,
#   '東門': 1051,
#   '古亭': 1292,
#   '頂溪': 1512,
#   '永安市場': 1644,
#   '景安': 1763,
#   '南勢角': 1888},
#  '三重國小': {'蘆洲': 467,
#   '三民高中': 356,
#   '徐匯中學': 239,
#   '三和國中': 132,
#   '三重國小': 25,
#   '大橋頭': 176,
#   '民權西路': 274,
#   '中山國小': 379,
#   '行天宮': 505,
#   '松江南京': 613,
#   '忠孝新生': 745,
#   '東門': 919,
#   '古亭': 1160,
#   '頂溪': 1380,
#   '永安市場': 1512,
#   '景安': 1631,
#   '南勢角': 1756},
#  '大橋頭': {'蘆洲': 643,
#   '三民高中': 532,
#   '徐匯中學': 415,
#   '三和國中': 308,
#   '三重國小': 176,
#   '大橋頭': 26,
#   '民權西路': 98,
#   '中山國小': 203,
#   '行天宮': 329,
#   '松江南京': 437,
#   '忠孝新生': 569,
#   '東門': 743,
#   '古亭': 984,
#   '頂溪': 1204,
#   '永安市場': 1336,
#   '景安': 1455,
#   '南勢角': 1580},
#  '民權西路': {'蘆洲': 741,
#   '三民高中': 630,
#   '徐匯中學': 513,
#   '三和國中': 406,
#   '三重國小': 274,
#   '大橋頭': 98,
#   '民權西路': 33,
#   '中山國小': 105,
#   '行天宮': 231,
#   '松江南京': 339,
#   '忠孝新生': 471,
#   '東門': 645,
#   '古亭': 886,
#   '頂溪': 1106,
#   '永安市場': 1238,
#   '景安': 1357,
#   '南勢角': 1482},
#  '中山國小': {'蘆洲': 846,
#   '三民高中': 735,
#   '徐匯中學': 618,
#   '三和國中': 511,
#   '三重國小': 379,
#   '大橋頭': 203,
#   '民權西路': 105,
#   '中山國小': 30,
#   '行天宮': 126,
#   '松江南京': 234,
#   '忠孝新生': 366,
#   '東門': 540,
#   '古亭': 781,
#   '頂溪': 1001,
#   '永安市場': 1133,
#   '景安': 1252,
#   '南勢角': 1377},
#  '行天宮': {'蘆洲': 972,
#   '三民高中': 861,
#   '徐匯中學': 744,
#   '三和國中': 637,
#   '三重國小': 505,
#   '大橋頭': 329,
#   '民權西路': 231,
#   '中山國小': 126,
#   '行天宮': 30,
#   '松江南京': 108,
#   '忠孝新生': 240,
#   '東門': 414,
#   '古亭': 655,
#   '頂溪': 875,
#   '永安市場': 1007,
#   '景安': 1126,
#   '南勢角': 1251},
#  '松江南京': {'蘆洲': 1080,
#   '三民高中': 969,
#   '徐匯中學': 852,
#   '三和國中': 745,
#   '三重國小': 613,
#   '大橋頭': 437,
#   '民權西路': 339,
#   '中山國小': 234,
#   '行天宮': 108,
#   '松江南京': 30,
#   '忠孝新生': 132,
#   '東門': 306,
#   '古亭': 547,
#   '頂溪': 767,
#   '永安市場': 899,
#   '景安': 1018,
#   '南勢角': 1143},
#  '忠孝新生': {'蘆洲': 1212,
#   '三民高中': 1101,
#   '徐匯中學': 984,
#   '三和國中': 877,
#   '三重國小': 745,
#   '大橋頭': 569,
#   '民權西路': 471,
#   '中山國小': 366,
#   '行天宮': 240,
#   '松江南京': 132,
#   '忠孝新生': 38,
#   '東門': 174,
#   '古亭': 415,
#   '頂溪': 635,
#   '永安市場': 767,
#   '景安': 886,
#   '南勢角': 1011},
#  '東門': {'蘆洲': 1386,
#   '三民高中': 1275,
#   '徐匯中學': 1158,
#   '三和國中': 1051,
#   '三重國小': 919,
#   '大橋頭': 743,
#   '民權西路': 645,
#   '中山國小': 540,
#   '行天宮': 414,
#   '松江南京': 306,
#   '忠孝新生': 174,
#   '東門': 33,
#   '古亭': 241,
#   '頂溪': 461,
#   '永安市場': 593,
#   '景安': 712,
#   '南勢角': 837},
#  '古亭': {'蘆洲': 1627,
#   '三民高中': 1516,
#   '徐匯中學': 1399,
#   '三和國中': 1292,
#   '三重國小': 1160,
#   '大橋頭': 984,
#   '民權西路': 886,
#   '中山國小': 781,
#   '行天宮': 655,
#   '松江南京': 547,
#   '忠孝新生': 415,
#   '東門': 241,
#   '古亭': 33,
#   '頂溪': 220,
#   '永安市場': 352,
#   '景安': 471,
#   '南勢角': 596},
#  '頂溪': {'蘆洲': 1847,
#   '三民高中': 1736,
#   '徐匯中學': 1619,
#   '三和國中': 1512,
#   '三重國小': 1380,
#   '大橋頭': 1204,
#   '民權西路': 1106,
#   '中山國小': 1001,
#   '行天宮': 875,
#   '松江南京': 767,
#   '忠孝新生': 635,
#   '東門': 461,
#   '古亭': 220,
#   '頂溪': 29,
#   '永安市場': 132,
#   '景安': 251,
#   '南勢角': 376},
#  '永安市場': {'蘆洲': 1979,
#   '三民高中': 1868,
#   '徐匯中學': 1751,
#   '三和國中': 1644,
#   '三重國小': 1512,
#   '大橋頭': 1336,
#   '民權西路': 1238,
#   '中山國小': 1133,
#   '行天宮': 1007,
#   '松江南京': 899,
#   '忠孝新生': 767,
#   '東門': 593,
#   '古亭': 352,
#   '頂溪': 132,
#   '永安市場': 29,
#   '景安': 119,
#   '南勢角': 244},
#  '景安': {'蘆洲': 2098,
#   '三民高中': 1987,
#   '徐匯中學': 1870,
#   '三和國中': 1763,
#   '三重國小': 1631,
#   '大橋頭': 1455,
#   '民權西路': 1357,
#   '中山國小': 1252,
#   '行天宮': 1126,
#   '松江南京': 1018,
#   '忠孝新生': 886,
#   '東門': 712,
#   '古亭': 471,
#   '頂溪': 251,
#   '永安市場': 119,
#   '景安': 28,
#   '南勢角': 125},
#  '南勢角': {'蘆洲': 2223,
#   '三民高中': 2112,
#   '徐匯中學': 1995,
#   '三和國中': 1888,
#   '三重國小': 1756,
#   '大橋頭': 1580,
#   '民權西路': 1482,
#   '中山國小': 1377,
#   '行天宮': 1251,
#   '松江南京': 1143,
#   '忠孝新生': 1011,
#   '東門': 837,
#   '古亭': 596,
#   '頂溪': 376,
#   '永安市場': 244,
#   '景安': 125,
#   '南勢角': 0}}

# %%
# open and read the transfer stations file
linetransfer_df = open_read('linetransfer.txt')
linetransfer_df
# Out:
#    FromLineNo FromLineID                                       FromLineName  \
# 0          BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 1           R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 2           R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 3           G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 4           G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 5           O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 6           R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 7           G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 8          BR         BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}
# 9          BR         BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}
# 10          G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 11         BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 12          R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 13         BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 14          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 15          R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 16         BR         BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}
# 17          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 18          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 19          G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 20         BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 21          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 22          Y          Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}
# 23         BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 24          G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 25          R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 26          R          R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}
# 27          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 28         BR         BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}
# 29          Y          Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}
# 30          G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 31         BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 32         BL         BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}
# 33          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 34          O          O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}
# 35          G          G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}
# 36          Y          Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}
# 37          Y          Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}
# 38          Y          Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}
#
#    FromStationID                                    FromStationName ToLineNo  \
# 0           BL23  {'Zh_tw': '南港展覽館', 'En': 'Taipei Nangang Exhib...       BR
# 1            R07                   {'Zh_tw': '東門', 'En': 'Dongmen'}        O
# 2            R11                 {'Zh_tw': '中山', 'En': 'Zhongshan'}        G
# 3            G16          {'Zh_tw': '南京復興', 'En': 'Nanjing Fuxing'}       BR
# 4            G15       {'Zh_tw': '松江南京', 'En': 'Songjiang Nanjing'}        O
# 5            O05                    {'Zh_tw': '古亭', 'En': 'Guting'}        G
# 6            R05                      {'Zh_tw': '大安', 'En': 'Daan'}       BR
# 7            G12                     {'Zh_tw': '西門', 'En': 'Ximen'}       BL
# 8           BR10        {'Zh_tw': '忠孝復興', 'En': 'Zhongxiao Fuxing'}       BL
# 9           BR24  {'Zh_tw': '南港展覽館', 'En': 'Taipei Nangang Exhib...       BL
# 10           G09                    {'Zh_tw': '古亭', 'En': 'Guting'}        O
# 11          BL14      {'Zh_tw': '忠孝新生', 'En': 'Zhongxiao Xinsheng'}        O
# 12           R13          {'Zh_tw': '民權西路', 'En': 'Minquan W. Rd.'}        O
# 13          BL11                     {'Zh_tw': '西門', 'En': 'Ximen'}        G
# 14           O12                {'Zh_tw': '大橋頭', 'En': 'Daqiaotou'}        O
# 15           R22                    {'Zh_tw': '北投', 'En': 'Beitou'}        R
# 16          BR09                      {'Zh_tw': '大安', 'En': 'Daan'}        R
# 17           O11          {'Zh_tw': '民權西路', 'En': 'Minquan W. Rd.'}        R
# 18           O07      {'Zh_tw': '忠孝新生', 'En': 'Zhongxiao Xinsheng'}       BL
# 19           G03                   {'Zh_tw': '七張', 'En': 'Qizhang'}        G
# 20          BL12     {'Zh_tw': '台北車站', 'En': 'Taipei Main Station'}        R
# 21           O02                    {'Zh_tw': '景安', 'En': 'Jingan'}        Y
# 22           Y16                   {'Zh_tw': '板橋', 'En': 'Banqiao'}       BL
# 23          BL15        {'Zh_tw': '忠孝復興', 'En': 'Zhongxiao Fuxing'}       BR
# 24           G10  {'Zh_tw': '中正紀念堂', 'En': 'Chiang Kai-Shek Memo...        R
# 25           R08  {'Zh_tw': '中正紀念堂', 'En': 'Chiang Kai-Shek Memo...        G
# 26           R10     {'Zh_tw': '台北車站', 'En': 'Taipei Main Station'}       BL
# 27           O17            {'Zh_tw': '頭前庄', 'En': 'Touqianzhuang'}        Y
# 28          BR11          {'Zh_tw': '南京復興', 'En': 'Nanjing Fuxing'}        G
# 29           Y07                {'Zh_tw': '大坪林', 'En': 'Dapinglin'}        G
# 30           G14                 {'Zh_tw': '中山', 'En': 'Zhongshan'}        R
# 31          BL08                     {'Zh_tw': '新埔', 'En': 'Xinpu'}        Y
# 32          BL07                   {'Zh_tw': '板橋', 'En': 'Banqiao'}        Y
# 33           O08       {'Zh_tw': '松江南京', 'En': 'Songjiang Nanjing'}        G
# 34           O06                   {'Zh_tw': '東門', 'En': 'Dongmen'}        R
# 35           G04                {'Zh_tw': '大坪林', 'En': 'Dapinglin'}        Y
# 36           Y17          {'Zh_tw': '新埔民生', 'En': 'Xinpu Minsheng'}       BL
# 37           Y18            {'Zh_tw': '頭前庄', 'En': 'Touqianzhuang'}        O
# 38           Y11                    {'Zh_tw': '景安', 'En': 'Jingan'}        O
#
#    ToLineID                                         ToLineName ToStationID  \
# 0        BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}        BR24
# 1         O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O06
# 2         G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G14
# 3        BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}        BR11
# 4         O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O08
# 5         G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G09
# 6        BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}        BR09
# 7        BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL11
# 8        BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL15
# 9        BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL23
# 10        O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O05
# 11        O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O07
# 12        O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O11
# 13        G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G12
# 14        O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O12
# 15        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R22
# 16        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R05
# 17        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R13
# 18       BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL14
# 19        G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G03
# 20        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R10
# 21        Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}         Y11
# 22       BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL07
# 23       BR               {'Zh_tw': '文湖線', 'En': 'Wenhu Line'}        BR10
# 24        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R08
# 25        G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G10
# 26       BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL12
# 27        Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}         Y18
# 28        G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G16
# 29        G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G04
# 30        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R11
# 31        Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}         Y17
# 32        Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}         Y16
# 33        G  {'Zh_tw': '松山新店線', 'En': 'Songshan-Xindian Line'}         G15
# 34        R      {'Zh_tw': '淡水信義線', 'En': 'Tamsui-Xinyi Line'}         R07
# 35        Y            {'Zh_tw': '環狀線', 'En': 'Circular Line'}         Y07
# 36       BL              {'Zh_tw': '板南線', 'En': 'Bannan Line'}        BL08
# 37        O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O17
# 38        O     {'Zh_tw': '中和新蘆線', 'En': 'Zhonghe-Xinlu Line'}         O02
#
#                                         ToStationName  IsOnSiteTransfer  \
# 0   {'Zh_tw': '南港展覽館', 'En': 'Taipei Nangang Exhib...                 1
# 1                    {'Zh_tw': '東門', 'En': 'Dongmen'}                 1
# 2                  {'Zh_tw': '中山', 'En': 'Zhongshan'}                 1
# 3           {'Zh_tw': '南京復興', 'En': 'Nanjing Fuxing'}                 1
# 4        {'Zh_tw': '松江南京', 'En': 'Songjiang Nanjing'}                 1
# 5                     {'Zh_tw': '古亭', 'En': 'Guting'}                 1
# 6                       {'Zh_tw': '大安', 'En': 'Daan'}                 1
# 7                      {'Zh_tw': '西門', 'En': 'Ximen'}                 1
# 8         {'Zh_tw': '忠孝復興', 'En': 'Zhongxiao Fuxing'}                 1
# 9   {'Zh_tw': '南港展覽館', 'En': 'Taipei Nangang Exhib...                 1
# 10                    {'Zh_tw': '古亭', 'En': 'Guting'}                 1
# 11      {'Zh_tw': '忠孝新生', 'En': 'Zhongxiao Xinsheng'}                 1
# 12          {'Zh_tw': '民權西路', 'En': 'Minquan W. Rd.'}                 1
# 13                     {'Zh_tw': '西門', 'En': 'Ximen'}                 1
# 14                {'Zh_tw': '大橋頭', 'En': 'Daqiaotou'}                 1
# 15                    {'Zh_tw': '北投', 'En': 'Beitou'}                 1
# 16                      {'Zh_tw': '大安', 'En': 'Daan'}                 1
# 17          {'Zh_tw': '民權西路', 'En': 'Minquan W. Rd.'}                 1
# 18      {'Zh_tw': '忠孝新生', 'En': 'Zhongxiao Xinsheng'}                 1
# 19                   {'Zh_tw': '七張', 'En': 'Qizhang'}                 1
# 20     {'Zh_tw': '台北車站', 'En': 'Taipei Main Station'}                 1
# 21                    {'Zh_tw': '景安', 'En': 'Jingan'}                 1
# 22                   {'Zh_tw': '板橋', 'En': 'Banqiao'}                 0
# 23        {'Zh_tw': '忠孝復興', 'En': 'Zhongxiao Fuxing'}                 1
# 24  {'Zh_tw': '中正紀念堂', 'En': 'Chiang Kai-Shek Memo...                 1
# 25  {'Zh_tw': '中正紀念堂', 'En': 'Chiang Kai-Shek Memo...                 1
# 26     {'Zh_tw': '台北車站', 'En': 'Taipei Main Station'}                 1
# 27            {'Zh_tw': '頭前庄', 'En': 'Touqianzhuang'}                 1
# 28          {'Zh_tw': '南京復興', 'En': 'Nanjing Fuxing'}                 1
# 29                {'Zh_tw': '大坪林', 'En': 'Dapinglin'}                 1
# 30                 {'Zh_tw': '中山', 'En': 'Zhongshan'}                 1
# 31          {'Zh_tw': '新埔民生', 'En': 'Xinpu Minsheng'}                 0
# 32                   {'Zh_tw': '板橋', 'En': 'Banqiao'}                 0
# 33       {'Zh_tw': '松江南京', 'En': 'Songjiang Nanjing'}                 1
# 34                   {'Zh_tw': '東門', 'En': 'Dongmen'}                 1
# 35                {'Zh_tw': '大坪林', 'En': 'Dapinglin'}                 1
# 36                     {'Zh_tw': '新埔', 'En': 'Xinpu'}                 0
# 37            {'Zh_tw': '頭前庄', 'En': 'Touqianzhuang'}                 1
# 38                    {'Zh_tw': '景安', 'En': 'Jingan'}                 1
#
#     TransferTime TransferDescription              SrcUpdateTime  \
# 0              5                      2020-01-31T14:00:00+08:00
# 1              2                      2020-01-31T14:00:00+08:00
# 2              3                      2020-01-31T14:00:00+08:00
# 3              5                      2020-01-31T14:00:00+08:00
# 4              2                      2020-01-31T14:00:00+08:00
# 5              2                      2020-01-31T14:00:00+08:00
# 6              5                      2020-01-31T14:00:00+08:00
# 7              2                      2020-01-31T14:00:00+08:00
# 8              5                      2020-01-31T14:00:00+08:00
# 9              5                      2020-01-31T14:00:00+08:00
# 10             2                      2020-01-31T14:00:00+08:00
# 11             2                      2020-01-31T14:00:00+08:00
# 12             3                      2020-01-31T14:00:00+08:00
# 13             2                      2020-01-31T14:00:00+08:00
# 14             1                      2020-01-31T14:00:00+08:00
# 15             3                      2020-01-31T14:00:00+08:00
# 16             5                      2020-01-31T14:00:00+08:00
# 17             3                      2020-01-31T14:00:00+08:00
# 18             2                      2020-01-31T14:00:00+08:00
# 19             3                      2020-01-31T14:00:00+08:00
# 20             4                      2020-01-31T14:00:00+08:00
# 21             6                      2020-01-31T14:00:00+08:00
# 22            11                      2020-01-31T14:00:00+08:00
# 23             5                      2020-01-31T14:00:00+08:00
# 24             2                      2020-01-31T14:00:00+08:00
# 25             2                      2020-01-31T14:00:00+08:00
# 26             4                      2020-01-31T14:00:00+08:00
# 27             6                      2020-01-31T14:00:00+08:00
# 28             5                      2020-01-31T14:00:00+08:00
# 29             3                      2020-01-31T14:00:00+08:00
# 30             3                      2020-01-31T14:00:00+08:00
# 31             9                      2020-01-31T14:00:00+08:00
# 32            11                      2020-01-31T14:00:00+08:00
# 33             2                      2020-01-31T14:00:00+08:00
# 34             2                      2020-01-31T14:00:00+08:00
# 35             3                      2020-01-31T14:00:00+08:00
# 36             9                      2020-01-31T14:00:00+08:00
# 37             6                      2020-01-31T14:00:00+08:00
# 38             6                      2020-01-31T14:00:00+08:00
#
#                    UpdateTime  VersionID
# 0   2020-05-20T12:00:00+08:00          2
# 1   2020-05-20T12:00:00+08:00          2
# 2   2020-05-20T12:00:00+08:00          2
# 3   2020-05-20T12:00:00+08:00          2
# 4   2020-05-20T12:00:00+08:00          2
# 5   2020-05-20T12:00:00+08:00          2
# 6   2020-05-20T12:00:00+08:00          2
# 7   2020-05-20T12:00:00+08:00          2
# 8   2020-05-20T12:00:00+08:00          2
# 9   2020-05-20T12:00:00+08:00          2
# 10  2020-05-20T12:00:00+08:00          2
# 11  2020-05-20T12:00:00+08:00          2
# 12  2020-05-20T12:00:00+08:00          2
# 13  2020-05-20T12:00:00+08:00          2
# 14  2020-05-20T12:00:00+08:00          2
# 15  2020-05-20T12:00:00+08:00          2
# 16  2020-05-20T12:00:00+08:00          2
# 17  2020-05-20T12:00:00+08:00          2
# 18  2020-05-20T12:00:00+08:00          2
# 19  2020-05-20T12:00:00+08:00          2
# 20  2020-05-20T12:00:00+08:00          2
# 21  2020-05-20T12:00:00+08:00          2
# 22  2020-05-20T12:00:00+08:00          2
# 23  2020-05-20T12:00:00+08:00          2
# 24  2020-05-20T12:00:00+08:00          2
# 25  2020-05-20T12:00:00+08:00          2
# 26  2020-05-20T12:00:00+08:00          2
# 27  2020-05-20T12:00:00+08:00          2
# 28  2020-05-20T12:00:00+08:00          2
# 29  2020-05-20T12:00:00+08:00          2
# 30  2020-05-20T12:00:00+08:00          2
# 31  2020-05-20T12:00:00+08:00          2
# 32  2020-05-20T12:00:00+08:00          2
# 33  2020-05-20T12:00:00+08:00          2
# 34  2020-05-20T12:00:00+08:00          2
# 35  2020-05-20T12:00:00+08:00          2
# 36  2020-05-20T12:00:00+08:00          2
# 37  2020-05-20T12:00:00+08:00          2
# 38  2020-05-20T12:00:00+08:00          2

# %%
def json_normalize(df):
    target_cols = ['FromLineName','FromStationName','ToLineName', 'ToStationName']
    for col in target_cols:
        df[col] = pd.json_normalize(df[col])
    return df

json_normalize(linetransfer_df).head(3)
# Out:
#   FromLineNo FromLineID FromLineName FromStationID FromStationName ToLineNo  \
# 0         BL         BL          板南線          BL23           南港展覽館       BR
# 1          R          R        淡水信義線           R07              東門        O
# 2          R          R        淡水信義線           R11              中山        G
#
#   ToLineID ToLineName ToStationID ToStationName  IsOnSiteTransfer  \
# 0       BR        文湖線        BR24         南港展覽館                 1
# 1        O      中和新蘆線         O06            東門                 1
# 2        G      松山新店線         G14            中山                 1
#
#    TransferTime TransferDescription              SrcUpdateTime  \
# 0             5                      2020-01-31T14:00:00+08:00
# 1             2                      2020-01-31T14:00:00+08:00
# 2             3                      2020-01-31T14:00:00+08:00
#
#                   UpdateTime  VersionID
# 0  2020-05-20T12:00:00+08:00          2
# 1  2020-05-20T12:00:00+08:00          2
# 2  2020-05-20T12:00:00+08:00          2

# %%
linetransfer_df['From_Line_Color'] = linetransfer_df['FromStationID'].apply(extract_color)
linetransfer_df['To_Line_Color'] = linetransfer_df['ToStationID'].apply(extract_color)

# remove two stations which are out of station
out_station_transfer = linetransfer_df[(linetransfer_df['FromStationName']=='新埔') | (linetransfer_df['FromStationName']=='新埔民生') | 
                                       (linetransfer_df['ToStationName']=='新埔') | (linetransfer_df['ToStationName']=='新埔民生') ]
linetransfer_df.drop(out_station_transfer.index, axis=0, inplace=True)

transfer_stations_df = linetransfer_df[['From_Line_Color', 'FromStationName', 'To_Line_Color', 'ToStationName']].sort_values(['From_Line_Color']).reset_index(drop=True)
transfer_stations_df
# Out:
#    From_Line_Color FromStationName To_Line_Color ToStationName
# 0             blue           南港展覽館         brown         南港展覽館
# 1             blue            忠孝復興         brown          忠孝復興
# 2             blue              西門         green            西門
# 3             blue            忠孝新生        orange          忠孝新生
# 4             blue              板橋        yellow            板橋
# 5             blue            台北車站           red          台北車站
# 6            brown            忠孝復興          blue          忠孝復興
# 7            brown           南港展覽館          blue         南港展覽館
# 8            brown            南京復興         green          南京復興
# 9            brown              大安           red            大安
# 10           green            松江南京        orange          松江南京
# 11           green              西門          blue            西門
# 12           green              七張         green            七張
# 13           green            南京復興         brown          南京復興
# 14           green              中山           red            中山
# 15           green           中正紀念堂           red         中正紀念堂
# 16           green             大坪林        yellow           大坪林
# 17           green              古亭        orange            古亭
# 18          orange              東門           red            東門
# 19          orange             頭前庄        yellow           頭前庄
# 20          orange            松江南京         green          松江南京
# 21          orange            忠孝新生          blue          忠孝新生
# 22          orange            民權西路           red          民權西路
# 23          orange             大橋頭        orange           大橋頭
# 24          orange              古亭         green            古亭
# 25          orange              景安        yellow            景安
# 26             red           中正紀念堂         green         中正紀念堂
# 27             red            台北車站          blue          台北車站
# 28             red              北投           red            北投
# 29             red            民權西路        orange          民權西路
# 30             red              大安         brown            大安
# 31             red              中山         green            中山
# 32             red              東門        orange            東門
# 33          yellow              板橋          blue            板橋
# 34          yellow             頭前庄        orange           頭前庄
# 35          yellow             大坪林         green           大坪林
# 36          yellow              景安        orange            景安

# %%
# purpose: get the line colors of thestation
def get_line_color(station_name):
    # pick up station_df in the MRT station ipynotebook
    station_df = pd.read_pickle("./station.pkl")
    color = station_df[station_df['StationName_Zh_tw']==station_name]['Line_Color']
    return color

# purpose: help to search commute time from one station to another station
def choose_searching_dict(color, isO2):
    if isO2:
        return commutetimes_dict['O-2']
    if color == 'yellow':
        return commutetimes_dict['Y-1']
    elif color == 'brown':
        return commutetimes_dict['BR-1']
    elif color == 'blue':
        return commutetimes_dict['BL-1']
    elif color == 'red':
        return commutetimes_dict['R-1']
    elif color == 'green':
        return commutetimes_dict['G-1']
    else:
        return commutetimes_dict['O-1']
        
def check_O2(station):
    O_2 = ['蘆洲', '三民高中', '徐匯中學', '三和國中', '三重國小']
    return station in O_2
     
# purpose: get the intersections to show all probable ways we can arrive the end_station
def find_intersections(start_station, end_station):
    
    # get the line colors of start_station and end_station
    start_line_color = get_line_color(start_station).values[0]
    end_line_color = get_line_color(end_station).values[0]
    
    with_start_color= transfer_stations_df[transfer_stations_df['From_Line_Color'] == start_line_color]
    with_end_color= transfer_stations_df[transfer_stations_df['To_Line_Color'] == end_line_color]
    start_intersect_end= pd.merge(with_start_color, with_end_color, left_on='To_Line_Color', right_on='From_Line_Color', suffixes=('_x', '_y'))
    
    return start_intersect_end[['From_Line_Color_x', 'To_Line_Color_x', 'ToStationName_x', 'ToStationName_y', 'To_Line_Color_y']], start_line_color, end_line_color

# %%
def get_trans_times(start, end):
    if get_line_color(start).values[0] == get_line_color(end).values[0]:
        return 0
    else:
        return 1
    
def get_total_taketime(start_station, end_station):
    # get line colors and intersect table
    transfer_table, start_line_color, end_line_color = find_intersections(start_station, end_station)
    trans_times = get_trans_times(start_station, end_station)
    O2_start_flag = check_O2(start_station)
    O2_end_flag = check_O2(end_station)
    O2_start_push = 0
    O2_end_push = 0
    if O2_start_flag and O2_end_flag:
        return choose_searching_dict(start_line_color, check_O2(start_station))[start_station][end_station]
    if O2_start_flag:
        O2_start_push = choose_searching_dict(start_line_color, check_O2(start_station))[start_station]["大橋頭"]
        start_station = "大橋頭"
    if O2_end_flag:
        O2_end_push = choose_searching_dict(end_line_color, check_O2(end_station))["大橋頭"][end_station]
        end_station = "大橋頭"
    
    # no transfer
    if trans_times == 0:
        return choose_searching_dict(start_line_color, check_O2(start_station))[start_station][end_station] + O2_start_push + O2_end_push
    # transfer > 0
    else:
        time_array = []
        for i in range(len(transfer_table)):
            time_sum = O2_start_push + O2_end_push
            # start_station -> intersect_from_station  
            time_sum = choose_searching_dict(start_line_color, check_O2(start_station))[start_station][transfer_table['ToStationName_x'][i]]
            # intersect_from_station -> intersect_to_station
            time_sum += choose_searching_dict(transfer_table['To_Line_Color_x'][i], False)[transfer_table['ToStationName_x'][i]][transfer_table['ToStationName_y'][i]]
            # intersect_to_station -> end_station
            time_sum += choose_searching_dict(end_line_color, check_O2(end_station))[transfer_table['ToStationName_y'][i]][end_station]

            time_array.append(time_sum)
        transfer_table["total_time"] = np.array(time_array)
        return transfer_table[transfer_table["total_time"] == transfer_table["total_time"].min()]["total_time"].values[0]

# %%
# get_total_taketime('三民高中', '南港')
get_total_taketime('淡水', '大橋頭')
# Out:
# 2042

# %%
best = get_total_taketime('三民高中','新店')
best
# Out:
# 1685

# %%
station_df = pd.read_pickle("./station.pkl")
station_df = station_df.drop(columns=['StationUID','LocationTownCode','StationName','StationAddress','BikeAllowOnHoliday','SrcUpdateTime','UpdateTime','VersionID','StationPosition', 'LocationCity', 'LocationCityCode', 'StationPosition_GeoHash'])
station_df = station_df[(station_df["StationName_Zh_tw"] != "小碧潭")]
station_df = station_df[(station_df["StationName_Zh_tw"] != "新北投")]
len(station_df["StationName_Zh_tw"].values)
# Out:
# 133

# %%
stations = station_df["StationName_Zh_tw"].values
from collections import defaultdict
all_time = defaultdict(dict)
for start in stations:
    for end in stations:
        all_time[start][end] = get_total_taketime(start,end)
all_time
# Out:
# defaultdict(dict,
#             {'中正紀念堂': {'中正紀念堂': 30,
#               '象山': 779,
#               '中山國中': 676,
#               '辛亥': 1169,
#               '圓山': 617,
#               '新北產業園區': 1537,
#               '竹圍': 2109,
#               '民權西路': 699,
#               '古亭': 479,
#               '士林': 876,
#               '東門': 396,
#               '橋和': 1265,
#               '港墘': 1393,
#               '台北橋': 753,
#               '頭前庄': 1319,
#               '台大醫院': 121,
#               '劍南路': 1168,
#               '六張犁': 923,
#               '行天宮': 568,
#               '南港展覽館': 1456,
#               '科技大樓': 776,
#               '三民高中': 627,
#               '大安': 677,
#               '台北車站': 412,
#               '唭哩岸': 1317,
#               '頂溪': 375,
#               '忠孝復興': 610,
#               '劍潭': 755,
#               '大坪林': 978,
#               '永寧': 1502,
#               '忠孝新生': 419,
#               '萬芳社區': 1424,
#               '蘆洲': 627,
#               '奇岩': 1415,
#               '信義安和': 537,
#               '迴龍': 1871,
#               '葫洲': 1747,
#               '公館': 673,
#               '北投': 1534,
#               '台北小巨蛋': 747,
#               '七張': 897,
#               '景平': 1036,
#               '南港軟體園區': 1534,
#               '南京復興': 615,
#               '木柵': 1496,
#               '小南門': 502,
#               '南勢角': 751,
#               '忠孝敦化': 602,
#               '景安': 626,
#               '新店區公所': 978,
#               '板橋': 856,
#               '台電大樓': 564,
#               '動物園': 1588,
#               '新莊': 1403,
#               '土城': 1381,
#               '亞東醫院': 1081,
#               '西門': 419,
#               '文德': 1490,
#               '松江南京': 546,
#               '忠義': 1831,
#               '海山': 1249,
#               '三重': 984,
#               '中山': 319,
#               '台北101/世貿': 657,
#               '十四張': 936,
#               '中原': 1320,
#               '永春': 918,
#               '昆陽': 1155,
#               '頂埔': 1710,
#               '西湖': 1303,
#               '淡水': 2447,
#               '龍山寺': 395,
#               '菜寮': 875,
#               '秀朗橋': 1070,
#               '芝山': 996,
#               '關渡': 1936,
#               '紅樹林': 2272,
#               '南京三民': 876,
#               '松山': 1014,
#               '後山埤': 1023,
#               '大直': 1040,
#               '內湖': 1593,
#               '景美': 940,
#               '新埔': 721,
#               '東湖': 1644,
#               '丹鳳': 1703,
#               '三重國小': 627,
#               '新埔民生': 1207,
#               '中山國小': 694,
#               '北門': 499,
#               '南港': 1288,
#               '大湖公園': 1689,
#               '輔大': 1565,
#               '大橋頭': 627,
#               '雙連': 409,
#               '松山機場': 843,
#               '板新': 1184,
#               '徐匯中學': 627,
#               '市政府': 806,
#               '復興崗': 1694,
#               '善導寺': 500,
#               '麟光': 1020,
#               '中和': 1136,
#               '明德': 1101,
#               '新店': 1114,
#               '府中': 951,
#               '先嗇宮': 1151,
#               '江子翠': 616,
#               '三和國中': 627,
#               '國父紀念館': 701,
#               '萬芳醫院': 1300,
#               '大安森林公園': 311,
#               '幸福': 1402,
#               '永安市場': 507,
#               '石牌': 1190,
#               '萬隆': 824},
#              '象山': {'中正紀念堂': 779,
#               '象山': 0,
#               '中山國中': 1455,
#               '辛亥': 1948,
#               '圓山': 1396,
#               '新北產業園區': 2253,
#               '竹圍': 2888,
#               '民權西路': 1415,
#               '古亭': 848,
#               '士林': 1655,
#               '東門': 1145,
#               '橋和': 1634,
#               '港墘': 2172,
#               '台北橋': 1469,
#               '頭前庄': 2035,
#               '台大醫院': 900,
#               '劍南路': 1947,
#               '六張犁': 1702,
#               '行天宮': 1347,
#               '南港展覽館': 2235,
#               '科技大樓': 1555,
#               '三民高中': 1343,
#               '大安': 1456,
#               '台北車站': 823,
#               '唭哩岸': 2096,
#               '頂溪': 1124,
#               '忠孝復興': 1389,
#               '劍潭': 1534,
#               '大坪林': 1428,
#               '永寧': 2237,
#               '忠孝新生': 611,
#               '萬芳社區': 2203,
#               '蘆洲': 1343,
#               '奇岩': 2194,
#               '信義安和': 242,
#               '迴龍': 2587,
#               '葫洲': 2526,
#               '公館': 1042,
#               '北投': 2313,
#               '台北小巨蛋': 708,
#               '七張': 1533,
#               '景平': 1405,
#               '南港軟體園區': 2313,
#               '南京復興': 1394,
#               '木柵': 2275,
#               '小南門': 1043,
#               '南勢角': 1500,
#               '忠孝敦化': 574,
#               '景安': 1375,
#               '新店區公所': 1638,
#               '板橋': 1591,
#               '台電大樓': 933,
#               '動物園': 2367,
#               '新莊': 2119,
#               '土城': 2116,
#               '亞東醫院': 1816,
#               '西門': 1128,
#               '文德': 2269,
#               '松江南京': 722,
#               '忠義': 2610,
#               '海山': 1984,
#               '三重': 1700,
#               '中山': 1098,
#               '台北101/世貿': 122,
#               '十四張': 1643,
#               '中原': 1731,
#               '永春': 890,
#               '昆陽': 1127,
#               '頂埔': 2445,
#               '西湖': 2082,
#               '淡水': 3226,
#               '龍山寺': 1130,
#               '菜寮': 1591,
#               '秀朗橋': 1509,
#               '芝山': 1775,
#               '關渡': 2715,
#               '紅樹林': 3051,
#               '南京三民': 837,
#               '松山': 975,
#               '後山埤': 995,
#               '大直': 1819,
#               '內湖': 2372,
#               '景美': 1309,
#               '新埔': 1456,
#               '東湖': 2423,
#               '丹鳳': 2419,
#               '三重國小': 1343,
#               '新埔民生': 1986,
#               '中山國小': 1473,
#               '北門': 1014,
#               '南港': 1260,
#               '大湖公園': 2468,
#               '輔大': 2281,
#               '大橋頭': 1343,
#               '雙連': 1188,
#               '松山機場': 1622,
#               '板新': 1867,
#               '徐匯中學': 1343,
#               '市政府': 778,
#               '復興崗': 2473,
#               '善導寺': 732,
#               '麟光': 1799,
#               '中和': 1505,
#               '明德': 1880,
#               '新店': 1774,
#               '府中': 1686,
#               '先嗇宮': 1867,
#               '江子翠': 1351,
#               '三和國中': 1343,
#               '國父紀念館': 673,
#               '萬芳醫院': 2079,
#               '大安森林公園': 468,
#               '幸福': 2118,
#               '永安市場': 1256,
#               '石牌': 1969,
#               '萬隆': 1193},
#              '中山國中': {'中正紀念堂': 676,
#               '象山': 1455,
#               '中山國中': 25,
#               '辛亥': 811,
#               '圓山': 655,
#               '新北產業園區': 1964,
#               '竹圍': 2147,
#               '民權西路': 555,
#               '古亭': 854,
#               '士林': 914,
#               '東門': 511,
#               '橋和': 1743,
#               '港墘': 717,
#               '台北橋': 805,
#               '頭前庄': 1711,
#               '台大醫院': 555,
#               '劍南路': 492,
#               '六張犁': 565,
#               '行天宮': 324,
#               '南港展覽館': 1450,
#               '科技大樓': 418,
#               '三民高中': 653,
#               '大安': 319,
#               '台北車站': 784,
#               '唭哩岸': 1355,
#               '頂溪': 972,
#               '忠孝復興': 207,
#               '劍潭': 793,
#               '大坪林': 1467,
#               '永寧': 1874,
#               '忠孝新生': 996,
#               '萬芳社區': 1066,
#               '蘆洲': 653,
#               '奇岩': 1453,
#               '信義安和': 1213,
#               '迴龍': 1923,
#               '葫洲': 1159,
#               '公館': 1081,
#               '北投': 1572,
#               '台北小巨蛋': 1353,
#               '七張': 1572,
#               '景平': 1986,
#               '南港軟體園區': 1372,
#               '南京復興': 91,
#               '木柵': 1138,
#               '小南門': 828,
#               '南勢角': 1348,
#               '忠孝敦化': 1219,
#               '景安': 1223,
#               '新店區公所': 1677,
#               '板橋': 1228,
#               '台電大樓': 972,
#               '動物園': 1230,
#               '新莊': 1455,
#               '土城': 1753,
#               '亞東醫院': 1453,
#               '西門': 745,
#               '文德': 814,
#               '松江南京': 1117,
#               '忠義': 1869,
#               '海山': 1621,
#               '三重': 1036,
#               '中山': 385,
#               '台北101/世貿': 1333,
#               '十四張': 1748,
#               '中原': 1646,
#               '永春': 1535,
#               '昆陽': 1772,
#               '頂埔': 2082,
#               '西湖': 627,
#               '淡水': 2485,
#               '龍山寺': 767,
#               '菜寮': 927,
#               '秀朗橋': 1882,
#               '芝山': 1034,
#               '關渡': 1974,
#               '紅樹林': 2310,
#               '南京三民': 1482,
#               '松山': 1620,
#               '後山埤': 1640,
#               '大直': 364,
#               '內湖': 917,
#               '景美': 1348,
#               '新埔': 1093,
#               '東湖': 1262,
#               '丹鳳': 1755,
#               '三重國小': 653,
#               '新埔民生': 1533,
#               '中山國小': 450,
#               '北門': 825,
#               '南港': 1905,
#               '大湖公園': 1013,
#               '輔大': 1617,
#               '大橋頭': 653,
#               '雙連': 447,
#               '松山機場': 167,
#               '板新': 1510,
#               '徐匯中學': 653,
#               '市政府': 1423,
#               '復興崗': 1732,
#               '善導寺': 875,
#               '麟光': 662,
#               '中和': 1872,
#               '明德': 1139,
#               '新店': 1813,
#               '府中': 1323,
#               '先嗇宮': 1203,
#               '江子翠': 988,
#               '三和國中': 653,
#               '國父紀念館': 1318,
#               '萬芳醫院': 942,
#               '大安森林公園': 987,
#               '幸福': 1829,
#               '永安市場': 1104,
#               '石牌': 1228,
#               '萬隆': 1232},
#              '辛亥': {'中正紀念堂': 1169,
#               '象山': 1948,
#               '中山國中': 811,
#               '辛亥': 25,
#               '圓山': 1284,
#               '新北產業園區': 2361,
#               '竹圍': 2776,
#               '民權西路': 1184,
#               '古亭': 1027,
#               '士林': 1543,
#               '東門': 730,
#               '橋和': 2140,
#               '港墘': 1528,
#               '台北橋': 1434,
#               '頭前庄': 2108,
#               '台大醫院': 1048,
#               '劍南路': 1303,
#               '六張犁': 246,
#               '行天宮': 953,
#               '南港展覽館': 2261,
#               '科技大樓': 393,
#               '三民高中': 1282,
#               '大安': 492,
#               '台北車站': 1167,
#               '唭哩岸': 1984,
#               '頂溪': 1158,
#               '忠孝復興': 604,
#               '劍潭': 1422,
#               '大坪林': 1640,
#               '永寧': 2503,
#               '忠孝新生': 1337,
#               '萬芳社區': 255,
#               '蘆洲': 1282,
#               '奇岩': 2082,
#               '信義安和': 1706,
#               '迴龍': 2552,
#               '葫洲': 1970,
#               '公館': 1254,
#               '北投': 2201,
#               '台北小巨蛋': 1598,
#               '七張': 1745,
#               '景平': 2607,
#               '南港軟體園區': 2183,
#               '南京復興': 720,
#               '木柵': 327,
#               '小南門': 1005,
#               '南勢角': 1534,
#               '忠孝敦化': 1560,
#               '景安': 1409,
#               '新店區公所': 1850,
#               '板橋': 1857,
#               '台電大樓': 1145,
#               '動物園': 419,
#               '新莊': 2084,
#               '土城': 2382,
#               '亞東醫院': 2082,
#               '西門': 1122,
#               '文德': 1625,
#               '松江南京': 1362,
#               '忠義': 2498,
#               '海山': 2250,
#               '三重': 1665,
#               '中山': 1014,
#               '台北101/世貿': 1826,
#               '十四張': 2377,
#               '中原': 2043,
#               '永春': 1876,
#               '昆陽': 2113,
#               '頂埔': 2711,
#               '西湖': 1438,
#               '淡水': 3114,
#               '龍山寺': 1396,
#               '菜寮': 1556,
#               '秀朗橋': 2511,
#               '芝山': 1663,
#               '關渡': 2603,
#               '紅樹林': 2939,
#               '南京三民': 1727,
#               '松山': 1865,
#               '後山埤': 1981,
#               '大直': 1175,
#               '內湖': 1728,
#               '景美': 1521,
#               '新埔': 1722,
#               '東湖': 2073,
#               '丹鳳': 2384,
#               '三重國小': 1282,
#               '新埔民生': 1930,
#               '中山國小': 1079,
#               '北門': 1222,
#               '南港': 2246,
#               '大湖公園': 1824,
#               '輔大': 2246,
#               '大橋頭': 1282,
#               '雙連': 1076,
#               '松山機場': 978,
#               '板新': 1907,
#               '徐匯中學': 1282,
#               '市政府': 1764,
#               '復興崗': 2361,
#               '善導寺': 1216,
#               '麟光': 149,
#               '中和': 2269,
#               '明德': 1768,
#               '新店': 1986,
#               '府中': 1952,
#               '先嗇宮': 1832,
#               '江子翠': 1617,
#               '三和國中': 1282,
#               '國父紀念館': 1659,
#               '萬芳醫院': 131,
#               '大安森林公園': 1480,
#               '幸福': 2226,
#               '永安市場': 1290,
#               '石牌': 1857,
#               '萬隆': 1405},
#              '圓山': {'中正紀念堂': 617,
#               '象山': 1396,
#               '中山國中': 655,
#               '辛亥': 1284,
#               '圓山': 26,
#               '新北產業園區': 1148,
#               '竹圍': 1492,
#               '民權西路': 310,
#               '古亭': 901,
#               '士林': 259,
#               '東門': 745,
#               '橋和': 1588,
#               '港墘': 1372,
#               '台北橋': 364,
#               '頭前庄': 930,
#               '台大醫院': 496,
#               '劍南路': 1147,
#               '六張犁': 1038,
#               '行天宮': 541,
#               '南港展覽館': 1627,
#               '科技大樓': 891,
#               '三民高中': 238,
#               '大安': 792,
#               '台北車站': 725,
#               '唭哩岸': 700,
#               '頂溪': 962,
#               '忠孝復興': 680,
#               '劍潭': 138,
#               '大坪林': 1514,
#               '永寧': 1815,
#               '忠孝新生': 625,
#               '萬芳社區': 1539,
#               '蘆洲': 238,
#               '奇岩': 798,
#               '信義安和': 1154,
#               '迴龍': 1482,
#               '葫洲': 1814,
#               '公館': 1128,
#               '北投': 917,
#               '台北小巨蛋': 689,
#               '七張': 1484,
#               '景平': 1590,
#               '南港軟體園區': 1705,
#               '南京復興': 594,
#               '木柵': 1611,
#               '小南門': 673,
#               '南勢角': 1338,
#               '忠孝敦化': 808,
#               '景安': 1213,
#               '新店區公所': 1565,
#               '板橋': 1169,
#               '台電大樓': 1019,
#               '動物園': 1703,
#               '新莊': 1014,
#               '土城': 1694,
#               '亞東醫院': 1394,
#               '西門': 590,
#               '文德': 1469,
#               '松江南京': 488,
#               '忠義': 1214,
#               '海山': 1562,
#               '三重': 595,
#               '中山': 298,
#               '台北101/世貿': 1274,
#               '十四張': 1523,
#               '中原': 1491,
#               '永春': 1124,
#               '昆陽': 1361,
#               '頂埔': 2023,
#               '西湖': 1282,
#               '淡水': 1830,
#               '龍山寺': 708,
#               '菜寮': 486,
#               '秀朗橋': 1657,
#               '芝山': 379,
#               '關渡': 1319,
#               '紅樹林': 1655,
#               '南京三民': 818,
#               '松山': 956,
#               '後山埤': 1229,
#               '大直': 1019,
#               '內湖': 1572,
#               '景美': 1395,
#               '新埔': 1034,
#               '東湖': 1815,
#               '丹鳳': 1314,
#               '三重國小': 238,
#               '新埔民生': 1073,
#               '中山國小': 415,
#               '北門': 670,
#               '南港': 1494,
#               '大湖公園': 1668,
#               '輔大': 1176,
#               '大橋頭': 238,
#               '雙連': 208,
#               '松山機場': 822,
#               '板新': 1355,
#               '徐匯中學': 238,
#               '市政府': 1012,
#               '復興崗': 1077,
#               '善導寺': 706,
#               '麟光': 1135,
#               '中和': 1690,
#               '明德': 484,
#               '新店': 1701,
#               '府中': 1264,
#               '先嗇宮': 762,
#               '江子翠': 929,
#               '三和國中': 238,
#               '國父紀念館': 907,
#               '萬芳醫院': 1415,
#               '大安森林公園': 928,
#               '幸福': 1013,
#               '永安市場': 1094,
#               '石牌': 573,
#               '萬隆': 1279},
#              '新北產業園區': {'中正紀念堂': 1537,
#               '象山': 2253,
#               '中山國中': 1964,
#               '辛亥': 2361,
#               '圓山': 1148,
#               '新北產業園區': 0,
#               '竹圍': 2640,
#               '民權西路': 1034,
#               '古亭': 1598,
#               '士林': 1407,
#               '東門': 1679,
#               '橋和': 1073,
#               '港墘': 2681,
#               '台北橋': 1088,
#               '頭前庄': 253,
#               '台大醫院': 1416,
#               '劍南路': 2456,
#               '六張犁': 2115,
#               '行天宮': 1265,
#               '南港展覽館': 2648,
#               '科技大樓': 1968,
#               '三民高中': 962,
#               '大安': 1869,
#               '台北車站': 1717,
#               '唭哩岸': 1848,
#               '頂溪': 2140,
#               '忠孝復興': 1802,
#               '劍潭': 1286,
#               '大坪林': 2156,
#               '永寧': 3131,
#               '忠孝新生': 1545,
#               '萬芳社區': 2616,
#               '蘆洲': 962,
#               '奇岩': 1946,
#               '信義安和': 2011,
#               '迴龍': 2206,
#               '葫洲': 2939,
#               '公館': 1825,
#               '北投': 2065,
#               '台北小巨蛋': 1609,
#               '七張': 2075,
#               '景平': 1540,
#               '南港軟體園區': 2726,
#               '南京復興': 1873,
#               '木柵': 2688,
#               '小南門': 1370,
#               '南勢角': 2516,
#               '忠孝敦化': 1728,
#               '景安': 2391,
#               '新店區公所': 2156,
#               '板橋': 2485,
#               '台電大樓': 1716,
#               '動物園': 2780,
#               '新莊': 1738,
#               '土城': 3010,
#               '亞東醫院': 2710,
#               '西門': 1287,
#               '文德': 2778,
#               '松江南京': 1408,
#               '忠義': 2362,
#               '海山': 2878,
#               '三重': 1319,
#               '中山': 1218,
#               '台北101/世貿': 2131,
#               '十四張': 1778,
#               '中原': 976,
#               '永春': 2044,
#               '昆陽': 2281,
#               '頂埔': 3339,
#               '西湖': 2591,
#               '淡水': 2978,
#               '龍山寺': 2024,
#               '菜寮': 1210,
#               '秀朗橋': 1644,
#               '芝山': 1527,
#               '關渡': 2467,
#               '紅樹林': 2803,
#               '南京三民': 1738,
#               '松山': 1876,
#               '後山埤': 2149,
#               '大直': 2328,
#               '內湖': 2881,
#               '景美': 2092,
#               '新埔': 2350,
#               '東湖': 2836,
#               '丹鳳': 2038,
#               '三重國小': 962,
#               '新埔民生': 431,
#               '中山國小': 1139,
#               '北門': 1367,
#               '南港': 2414,
#               '大湖公園': 2977,
#               '輔大': 1900,
#               '大橋頭': 962,
#               '雙連': 1128,
#               '松山機場': 2131,
#               '板新': 840,
#               '徐匯中學': 962,
#               '市政府': 1932,
#               '復興崗': 2225,
#               '善導寺': 1626,
#               '麟光': 2212,
#               '中和': 1202,
#               '明德': 1632,
#               '新店': 2292,
#               '府中': 2580,
#               '先嗇宮': 1486,
#               '江子翠': 2245,
#               '三和國中': 962,
#               '國父紀念館': 1827,
#               '萬芳醫院': 2492,
#               '大安森林公園': 1785,
#               '幸福': 135,
#               '永安市場': 2272,
#               '石牌': 1721,
#               '萬隆': 1976},
#              '竹圍': {'中正紀念堂': 2109,
#               '象山': 2888,
#               '中山國中': 2147,
#               '辛亥': 2776,
#               '圓山': 1492,
#               '新北產業園區': 2640,
#               '竹圍': 25,
#               '民權西路': 1639,
#               '古亭': 2234,
#               '士林': 1233,
#               '東門': 2237,
#               '橋和': 3080,
#               '港墘': 2864,
#               '台北橋': 1856,
#               '頭前庄': 2422,
#               '台大醫院': 1988,
#               '劍南路': 2639,
#               '六張犁': 2530,
#               '行天宮': 1837,
#               '南港展覽館': 3119,
#               '科技大樓': 2383,
#               '三民高中': 1704,
#               '大安': 2284,
#               '台北車站': 1928,
#               '唭哩岸': 792,
#               '頂溪': 2454,
#               '忠孝復興': 2172,
#               '劍潭': 1354,
#               '大坪林': 2847,
#               '永寧': 3300,
#               '忠孝新生': 2098,
#               '萬芳社區': 3031,
#               '蘆洲': 1704,
#               '奇岩': 694,
#               '信義安和': 2646,
#               '迴龍': 2974,
#               '葫洲': 3306,
#               '公館': 2461,
#               '北投': 575,
#               '台北小巨蛋': 2167,
#               '七張': 2952,
#               '景平': 3082,
#               '南港軟體園區': 3197,
#               '南京復興': 2086,
#               '木柵': 3103,
#               '小南門': 2165,
#               '南勢角': 2830,
#               '忠孝敦化': 2300,
#               '景安': 2705,
#               '新店區公所': 3057,
#               '板橋': 2654,
#               '台電大樓': 2352,
#               '動物園': 3195,
#               '新莊': 2506,
#               '土城': 3179,
#               '亞東醫院': 2879,
#               '西門': 2055,
#               '文德': 2961,
#               '松江南京': 1931,
#               '忠義': 278,
#               '海山': 3047,
#               '三重': 2087,
#               '中山': 1790,
#               '台北101/世貿': 2766,
#               '十四張': 3015,
#               '中原': 2983,
#               '永春': 2616,
#               '昆陽': 2853,
#               '頂埔': 3508,
#               '西湖': 2774,
#               '淡水': 338,
#               '龍山寺': 2193,
#               '菜寮': 1978,
#               '秀朗橋': 3149,
#               '芝山': 1113,
#               '關渡': 173,
#               '紅樹林': 163,
#               '南京三民': 2296,
#               '松山': 2434,
#               '後山埤': 2721,
#               '大直': 2511,
#               '內湖': 3064,
#               '景美': 2728,
#               '新埔': 2519,
#               '東湖': 3307,
#               '丹鳳': 2806,
#               '三重國小': 1704,
#               '新埔民生': 2565,
#               '中山國小': 1711,
#               '北門': 1941,
#               '南港': 2986,
#               '大湖公園': 3160,
#               '輔大': 2668,
#               '大橋頭': 1704,
#               '雙連': 1700,
#               '松山機場': 2314,
#               '板新': 2847,
#               '徐匯中學': 1704,
#               '市政府': 2504,
#               '復興崗': 415,
#               '善導寺': 1977,
#               '麟光': 2627,
#               '中和': 3182,
#               '明德': 1008,
#               '新店': 3193,
#               '府中': 2749,
#               '先嗇宮': 2254,
#               '江子翠': 2414,
#               '三和國中': 1704,
#               '國父紀念館': 2399,
#               '萬芳醫院': 2907,
#               '大安森林公園': 2420,
#               '幸福': 2505,
#               '永安市場': 2586,
#               '石牌': 919,
#               '萬隆': 2612},
#              '民權西路': {'中正紀念堂': 699,
#               '象山': 1415,
#               '中山國中': 555,
#               '辛亥': 1184,
#               '圓山': 310,
#               '新北產業園區': 1034,
#               '竹圍': 1639,
#               '民權西路': 33,
#               '古亭': 661,
#               '士林': 569,
#               '東門': 645,
#               '橋和': 1601,
#               '港墘': 1272,
#               '台北橋': 250,
#               '頭前庄': 816,
#               '台大醫院': 578,
#               '劍南路': 1047,
#               '六張犁': 938,
#               '行天宮': 231,
#               '南港展覽館': 1492,
#               '科技大樓': 791,
#               '三民高中': 630,
#               '大安': 692,
#               '台北車站': 355,
#               '唭哩岸': 1010,
#               '頂溪': 1106,
#               '忠孝復興': 580,
#               '劍潭': 448,
#               '大坪林': 1274,
#               '永寧': 1727,
#               '忠孝新生': 525,
#               '萬芳社區': 1439,
#               '蘆洲': 741,
#               '奇岩': 1108,
#               '信義安和': 1173,
#               '迴龍': 1368,
#               '葫洲': 1714,
#               '公館': 888,
#               '北投': 1092,
#               '台北小巨蛋': 594,
#               '七張': 1379,
#               '景平': 1672,
#               '南港軟體園區': 1570,
#               '南京復興': 494,
#               '木柵': 1511,
#               '小南門': 599,
#               '南勢角': 1482,
#               '忠孝敦化': 748,
#               '景安': 1357,
#               '新店區公所': 1484,
#               '板橋': 1081,
#               '台電大樓': 779,
#               '動物園': 1603,
#               '新莊': 900,
#               '土城': 1606,
#               '亞東醫院': 1306,
#               '西門': 482,
#               '文德': 1369,
#               '松江南京': 358,
#               '忠義': 1361,
#               '海山': 1474,
#               '三重': 481,
#               '中山': 380,
#               '台北101/世貿': 1293,
#               '十四張': 1667,
#               '中原': 1504,
#               '永春': 1064,
#               '昆陽': 1301,
#               '頂埔': 1935,
#               '西湖': 1182,
#               '淡水': 1977,
#               '龍山寺': 620,
#               '菜寮': 372,
#               '秀朗橋': 1776,
#               '芝山': 689,
#               '關渡': 1466,
#               '紅樹林': 1802,
#               '南京三民': 723,
#               '松山': 861,
#               '後山埤': 1169,
#               '大直': 919,
#               '內湖': 1472,
#               '景美': 1155,
#               '新埔': 946,
#               '東湖': 1680,
#               '丹鳳': 1200,
#               '三重國小': 274,
#               '新埔民生': 959,
#               '中山國小': 105,
#               '北門': 368,
#               '南港': 1434,
#               '大湖公園': 1568,
#               '輔大': 1062,
#               '大橋頭': 98,
#               '雙連': 290,
#               '松山機場': 722,
#               '板新': 1368,
#               '徐匯中學': 513,
#               '市政府': 952,
#               '復興崗': 1224,
#               '善導寺': 404,
#               '麟光': 1035,
#               '中和': 1730,
#               '明德': 794,
#               '新店': 1620,
#               '府中': 1176,
#               '先嗇宮': 648,
#               '江子翠': 841,
#               '三和國中': 406,
#               '國父紀念館': 847,
#               '萬芳醫院': 1315,
#               '大安森林公園': 947,
#               '幸福': 899,
#               '永安市場': 1238,
#               '石牌': 883,
#               '萬隆': 1039},
#              '古亭': {'中正紀念堂': 479,
#               '象山': 848,
#               '中山國中': 854,
#               '辛亥': 1027,
#               '圓山': 901,
#               '新北產業園區': 1598,
#               '竹圍': 2234,
#               '民權西路': 661,
#               '古亭': 33,
#               '士林': 1160,
#               '東門': 363,
#               '橋和': 852,
#               '港墘': 1571,
#               '台北橋': 878,
#               '頭前庄': 1345,
#               '台大醫院': 600,
#               '劍南路': 1346,
#               '六張犁': 781,
#               '行天宮': 744,
#               '南港展覽館': 1740,
#               '科技大樓': 634,
#               '三民高中': 726,
#               '大安': 565,
#               '台北車站': 390,
#               '唭哩岸': 1601,
#               '頂溪': 791,
#               '忠孝復興': 647,
#               '劍潭': 1039,
#               '大坪林': 613,
#               '永寧': 1762,
#               '忠孝新生': 488,
#               '萬芳社區': 1282,
#               '蘆洲': 726,
#               '奇岩': 1699,
#               '信義安和': 606,
#               '迴龍': 1996,
#               '葫洲': 2013,
#               '公館': 227,
#               '北投': 1687,
#               '台北小巨蛋': 987,
#               '七張': 718,
#               '景平': 623,
#               '南港軟體園區': 1818,
#               '南京復興': 763,
#               '木柵': 1354,
#               '小南門': 228,
#               '南勢角': 1167,
#               '忠孝敦化': 671,
#               '景安': 1042,
#               '新店區公所': 823,
#               '板橋': 1116,
#               '台電大樓': 118,
#               '動物園': 1446,
#               '新莊': 1528,
#               '土城': 1641,
#               '亞東醫院': 1341,
#               '西門': 345,
#               '文德': 1668,
#               '松江南京': 751,
#               '忠義': 1956,
#               '海山': 1509,
#               '三重': 1109,
#               '中山': 603,
#               '台北101/世貿': 726,
#               '十四張': 861,
#               '中原': 949,
#               '永春': 987,
#               '昆陽': 1224,
#               '頂埔': 1970,
#               '西湖': 1481,
#               '淡水': 2572,
#               '龍山寺': 655,
#               '菜寮': 1000,
#               '秀朗橋': 727,
#               '芝山': 1280,
#               '關渡': 2061,
#               '紅樹林': 2397,
#               '南京三民': 1116,
#               '松山': 1254,
#               '後山埤': 1092,
#               '大直': 1218,
#               '內湖': 1771,
#               '景美': 494,
#               '新埔': 981,
#               '東湖': 1928,
#               '丹鳳': 1828,
#               '三重國小': 726,
#               '新埔民生': 1167,
#               '中山國小': 733,
#               '北門': 459,
#               '南港': 1357,
#               '大湖公園': 1867,
#               '輔大': 1690,
#               '大橋頭': 726,
#               '雙連': 693,
#               '松山機場': 1021,
#               '板新': 1085,
#               '徐匯中學': 726,
#               '市政府': 875,
#               '復興崗': 1819,
#               '善導寺': 439,
#               '麟光': 878,
#               '中和': 723,
#               '明德': 1385,
#               '新店': 959,
#               '府中': 1211,
#               '先嗇宮': 1276,
#               '江子翠': 876,
#               '三和國中': 726,
#               '國父紀念館': 770,
#               '萬芳醫院': 1158,
#               '大安森林公園': 380,
#               '幸福': 1463,
#               '永安市場': 923,
#               '石牌': 1474,
#               '萬隆': 378},
#              '士林': {'中正紀念堂': 876,
#               '象山': 1655,
#               '中山國中': 914,
#               '辛亥': 1543,
#               '圓山': 259,
#               '新北產業園區': 1407,
#               '竹圍': 1233,
#               '民權西路': 569,
#               '古亭': 1160,
#               '士林': 26,
#               '東門': 1004,
#               '橋和': 1847,
#               '港墘': 1631,
#               '台北橋': 623,
#               '頭前庄': 1189,
#               '台大醫院': 755,
#               '劍南路': 1406,
#               '六張犁': 1297,
#               '行天宮': 800,
#               '南港展覽館': 1886,
#               '科技大樓': 1150,
#               '三民高中': 497,
#               '大安': 1051,
#               '台北車站': 984,
#               '唭哩岸': 441,
#               '頂溪': 1221,
#               '忠孝復興': 939,
#               '劍潭': 121,
#               '大坪林': 1773,
#               '永寧': 2074,
#               '忠孝新生': 884,
#               '萬芳社區': 1798,
#               '蘆洲': 497,
#               '奇岩': 539,
#               '信義安和': 1413,
#               '迴龍': 1741,
#               '葫洲': 2073,
#               '公館': 1387,
#               '北投': 658,
#               '台北小巨蛋': 948,
#               '七張': 1743,
#               '景平': 1849,
#               '南港軟體園區': 1964,
#               '南京復興': 853,
#               '木柵': 1870,
#               '小南門': 932,
#               '南勢角': 1597,
#               '忠孝敦化': 1067,
#               '景安': 1472,
#               '新店區公所': 1824,
#               '板橋': 1428,
#               '台電大樓': 1278,
#               '動物園': 1962,
#               '新莊': 1273,
#               '土城': 1953,
#               '亞東醫院': 1653,
#               '西門': 849,
#               '文德': 1728,
#               '松江南京': 747,
#               '忠義': 955,
#               '海山': 1821,
#               '三重': 854,
#               '中山': 557,
#               '台北101/世貿': 1533,
#               '十四張': 1782,
#               '中原': 1750,
#               '永春': 1383,
#               '昆陽': 1620,
#               '頂埔': 2282,
#               '西湖': 1541,
#               '淡水': 1571,
#               '龍山寺': 967,
#               '菜寮': 745,
#               '秀朗橋': 1916,
#               '芝山': 120,
#               '關渡': 1060,
#               '紅樹林': 1396,
#               '南京三民': 1077,
#               '松山': 1215,
#               '後山埤': 1488,
#               '大直': 1278,
#               '內湖': 1831,
#               '景美': 1654,
#               '新埔': 1293,
#               '東湖': 2074,
#               '丹鳳': 1573,
#               '三重國小': 497,
#               '新埔民生': 1332,
#               '中山國小': 674,
#               '北門': 929,
#               '南港': 1753,
#               '大湖公園': 1927,
#               '輔大': 1435,
#               '大橋頭': 497,
#               '雙連': 467,
#               '松山機場': 1081,
#               '板新': 1614,
#               '徐匯中學': 497,
#               '市政府': 1271,
#               '復興崗': 818,
#               '善導寺': 965,
#               '麟光': 1394,
#               '中和': 1949,
#               '明德': 225,
#               '新店': 1960,
#               '府中': 1523,
#               '先嗇宮': 1021,
#               '江子翠': 1188,
#               '三和國中': 497,
#               '國父紀念館': 1166,
#               '萬芳醫院': 1674,
#               '大安森林公園': 1187,
#               '幸福': 1272,
#               '永安市場': 1353,
#               '石牌': 314,
#               '萬隆': 1538},
#              '東門': {'中正紀念堂': 396,
#               '象山': 1145,
#               '中山國中': 511,
#               '辛亥': 730,
#               '圓山': 745,
#               '新北產業園區': 1679,
#               '竹圍': 2237,
#               '民權西路': 645,
#               '古亭': 363,
#               '士林': 1004,
#               '東門': 33,
#               '橋和': 1580,
#               '港墘': 1228,
#               '台北橋': 895,
#               '頭前庄': 1461,
#               '台大醫院': 487,
#               '劍南路': 1003,
#               '六張犁': 484,
#               '行天宮': 414,
#               '南港展覽館': 1195,
#               '科技大樓': 337,
#               '三民高中': 1275,
#               '大安': 268,
#               '台北車站': 503,
#               '唭哩岸': 1445,
#               '頂溪': 461,
#               '忠孝復興': 349,
#               '劍潭': 883,
#               '大坪林': 976,
#               '永寧': 1838,
#               '忠孝新生': 673,
#               '萬芳社區': 985,
#               '蘆洲': 1386,
#               '奇岩': 1543,
#               '信義安和': 903,
#               '迴龍': 2013,
#               '葫洲': 1486,
#               '公館': 590,
#               '北投': 1662,
#               '台北小巨蛋': 934,
#               '七張': 983,
#               '景平': 1260,
#               '南港軟體園區': 1273,
#               '南京復興': 420,
#               '木柵': 1057,
#               '小南門': 341,
#               '南勢角': 837,
#               '忠孝敦化': 896,
#               '景安': 712,
#               '新店區公所': 1064,
#               '板橋': 1192,
#               '台電大樓': 481,
#               '動物園': 1149,
#               '新莊': 1545,
#               '土城': 1717,
#               '亞東醫院': 1417,
#               '西門': 458,
#               '文德': 1325,
#               '松江南京': 698,
#               '忠義': 1959,
#               '海山': 1585,
#               '三重': 1126,
#               '中山': 475,
#               '台北101/世貿': 1023,
#               '十四張': 1022,
#               '中原': 1483,
#               '永春': 1212,
#               '昆陽': 1449,
#               '頂埔': 2046,
#               '西湖': 1138,
#               '淡水': 2575,
#               '龍山寺': 731,
#               '菜寮': 1017,
#               '秀朗橋': 1156,
#               '芝山': 1124,
#               '關渡': 2064,
#               '紅樹林': 2400,
#               '南京三民': 1063,
#               '松山': 1201,
#               '後山埤': 1317,
#               '大直': 875,
#               '內湖': 1428,
#               '景美': 857,
#               '新埔': 1057,
#               '東湖': 1383,
#               '丹鳳': 1845,
#               '三重國小': 919,
#               '新埔民生': 1370,
#               '中山國小': 540,
#               '北門': 572,
#               '南港': 1582,
#               '大湖公園': 1524,
#               '輔大': 1707,
#               '大橋頭': 743,
#               '雙連': 537,
#               '松山機場': 678,
#               '板新': 1347,
#               '徐匯中學': 1158,
#               '市政府': 1100,
#               '復興崗': 1822,
#               '善導寺': 552,
#               '麟光': 581,
#               '中和': 1598,
#               '明德': 1229,
#               '新店': 1200,
#               '府中': 1287,
#               '先嗇宮': 1293,
#               '江子翠': 952,
#               '三和國中': 1051,
#               '國父紀念館': 995,
#               '萬芳醫院': 861,
#               '大安森林公園': 677,
#               '幸福': 1544,
#               '永安市場': 593,
#               '石牌': 1318,
#               '萬隆': 741},
#              '橋和': {'中正紀念堂': 1265,
#               '象山': 1634,
#               '中山國中': 1743,
#               '辛亥': 2140,
#               '圓山': 1588,
#               '新北產業園區': 1073,
#               '竹圍': 3080,
#               '民權西路': 1601,
#               '古亭': 852,
#               '士林': 1847,
#               '東門': 1580,
#               '橋和': 25,
#               '港墘': 2460,
#               '台北橋': 1655,
#               '頭前庄': 820,
#               '台大醫院': 1296,
#               '劍南路': 2235,
#               '六張犁': 1894,
#               '行天宮': 1646,
#               '南港展覽館': 2427,
#               '科技大樓': 1747,
#               '三民高中': 1529,
#               '大安': 1648,
#               '台北車站': 1446,
#               '唭哩岸': 2288,
#               '頂溪': 1706,
#               '忠孝復興': 1581,
#               '劍潭': 1726,
#               '大坪林': 1083,
#               '永寧': 2860,
#               '忠孝新生': 1274,
#               '萬芳社區': 2395,
#               '蘆洲': 1529,
#               '奇岩': 2386,
#               '信義安和': 1392,
#               '迴龍': 2773,
#               '葫洲': 2718,
#               '公館': 1046,
#               '北投': 2505,
#               '台北小巨蛋': 1602,
#               '七張': 1002,
#               '景平': 467,
#               '南港軟體園區': 2505,
#               '南京復興': 1652,
#               '木柵': 2467,
#               '小南門': 1047,
#               '南勢角': 2082,
#               '忠孝敦化': 1457,
#               '景安': 1957,
#               '新店區公所': 1083,
#               '板橋': 2214,
#               '台電大樓': 937,
#               '動物園': 2559,
#               '新莊': 2305,
#               '土城': 2739,
#               '亞東醫院': 2439,
#               '西門': 1066,
#               '文德': 2557,
#               '松江南京': 1401,
#               '忠義': 2802,
#               '海山': 2607,
#               '三重': 1886,
#               '中山': 1290,
#               '台北101/世貿': 1512,
#               '十四張': 705,
#               '中原': 97,
#               '永春': 1773,
#               '昆陽': 2010,
#               '頂埔': 3068,
#               '西湖': 2370,
#               '淡水': 3418,
#               '龍山寺': 1753,
#               '菜寮': 1777,
#               '秀朗橋': 571,
#               '芝山': 1967,
#               '關渡': 2907,
#               '紅樹林': 3243,
#               '南京三民': 1731,
#               '松山': 1869,
#               '後山埤': 1878,
#               '大直': 2107,
#               '內湖': 2660,
#               '景美': 1202,
#               '新埔': 2079,
#               '東湖': 2615,
#               '丹鳳': 2605,
#               '三重國小': 1529,
#               '新埔民生': 642,
#               '中山國小': 1706,
#               '北門': 1146,
#               '南港': 2143,
#               '大湖公園': 2756,
#               '輔大': 2467,
#               '大橋頭': 1529,
#               '雙連': 1380,
#               '松山機場': 1910,
#               '板新': 233,
#               '徐匯中學': 1529,
#               '市政府': 1661,
#               '復興崗': 2665,
#               '善導寺': 1355,
#               '麟光': 1991,
#               '中和': 129,
#               '明德': 2072,
#               '新店': 1219,
#               '府中': 2309,
#               '先嗇宮': 2053,
#               '江子翠': 1974,
#               '三和國中': 1529,
#               '國父紀念館': 1556,
#               '萬芳醫院': 2271,
#               '大安森林公園': 1166,
#               '幸福': 938,
#               '永安市場': 1838,
#               '石牌': 2161,
#               '萬隆': 1197},
#              '港墘': {'中正紀念堂': 1393,
#               '象山': 2172,
#               '中山國中': 717,
#               '辛亥': 1528,
#               '圓山': 1372,
#               '新北產業園區': 2681,
#               '竹圍': 2864,
#               '民權西路': 1272,
#               '古亭': 1571,
#               '士林': 1631,
#               '東門': 1228,
#               '橋和': 2460,
#               '港墘': 25,
#               '台北橋': 1522,
#               '頭前庄': 2428,
#               '台大醫院': 1272,
#               '劍南路': 225,
#               '六張犁': 1282,
#               '行天宮': 1041,
#               '南港展覽館': 733,
#               '科技大樓': 1135,
#               '三民高中': 1370,
#               '大安': 1036,
#               '台北車站': 1501,
#               '唭哩岸': 2072,
#               '頂溪': 1689,
#               '忠孝復興': 924,
#               '劍潭': 1510,
#               '大坪林': 2184,
#               '永寧': 2591,
#               '忠孝新生': 1713,
#               '萬芳社區': 1783,
#               '蘆洲': 1370,
#               '奇岩': 2170,
#               '信義安和': 1930,
#               '迴龍': 2640,
#               '葫洲': 442,
#               '公館': 1798,
#               '北投': 2289,
#               '台北小巨蛋': 2070,
#               '七張': 2289,
#               '景平': 2703,
#               '南港軟體園區': 655,
#               '南京復興': 808,
#               '木柵': 1855,
#               '小南門': 1545,
#               '南勢角': 2065,
#               '忠孝敦化': 1936,
#               '景安': 1940,
#               '新店區公所': 2394,
#               '板橋': 1945,
#               '台電大樓': 1689,
#               '動物園': 1947,
#               '新莊': 2172,
#               '土城': 2470,
#               '亞東醫院': 2170,
#               '西門': 1462,
#               '文德': 97,
#               '松江南京': 1834,
#               '忠義': 2586,
#               '海山': 2338,
#               '三重': 1753,
#               '中山': 1102,
#               '台北101/世貿': 2050,
#               '十四張': 2465,
#               '中原': 2363,
#               '永春': 2252,
#               '昆陽': 2489,
#               '頂埔': 2799,
#               '西湖': 90,
#               '淡水': 3202,
#               '龍山寺': 1484,
#               '菜寮': 1644,
#               '秀朗橋': 2599,
#               '芝山': 1751,
#               '關渡': 2691,
#               '紅樹林': 3027,
#               '南京三民': 2199,
#               '松山': 2337,
#               '後山埤': 2357,
#               '大直': 353,
#               '內湖': 200,
#               '景美': 2065,
#               '新埔': 1810,
#               '東湖': 545,
#               '丹鳳': 2472,
#               '三重國小': 1370,
#               '新埔民生': 2250,
#               '中山國小': 1167,
#               '北門': 1542,
#               '南港': 2622,
#               '大湖公園': 296,
#               '輔大': 2334,
#               '大橋頭': 1370,
#               '雙連': 1164,
#               '松山機場': 550,
#               '板新': 2227,
#               '徐匯中學': 1370,
#               '市政府': 2140,
#               '復興崗': 2449,
#               '善導寺': 1592,
#               '麟光': 1379,
#               '中和': 2589,
#               '明德': 1856,
#               '新店': 2530,
#               '府中': 2040,
#               '先嗇宮': 1920,
#               '江子翠': 1705,
#               '三和國中': 1370,
#               '國父紀念館': 2035,
#               '萬芳醫院': 1659,
#               '大安森林公園': 1704,
#               '幸福': 2546,
#               '永安市場': 1821,
#               '石牌': 1945,
#               '萬隆': 1949},
#              '台北橋': {'中正紀念堂': 753,
#               '象山': 1469,
#               '中山國中': 805,
#               '辛亥': 1434,
#               '圓山': 364,
#               '新北產業園區': 1088,
#               '竹圍': 1856,
#               '民權西路': 250,
#               '古亭': 878,
#               '士林': 623,
#               '東門': 895,
#               '橋和': 1655,
#               '港墘': 1522,
#               '台北橋': 25,
#               '頭前庄': 870,
#               '台大醫院': 632,
#               '劍南路': 1297,
#               '六張犁': 1188,
#               '行天宮': 481,
#               '南港展覽館': 1742,
#               '科技大樓': 1041,
#               '三民高中': 684,
#               '大安': 942,
#               '台北車站': 572,
#               '唭哩岸': 1064,
#               '頂溪': 1356,
#               '忠孝復興': 830,
#               '劍潭': 502,
#               '大坪林': 1491,
#               '永寧': 1571,
#               '忠孝新生': 742,
#               '萬芳社區': 1689,
#               '蘆洲': 795,
#               '奇岩': 1162,
#               '信義安和': 1227,
#               '迴龍': 1118,
#               '葫洲': 1964,
#               '公館': 1105,
#               '北投': 1281,
#               '台北小巨蛋': 811,
#               '七張': 1596,
#               '景平': 1726,
#               '南港軟體園區': 1820,
#               '南京復興': 744,
#               '木柵': 1761,
#               '小南門': 816,
#               '南勢角': 1732,
#               '忠孝敦化': 944,
#               '景安': 1607,
#               '新店區公所': 1701,
#               '板橋': 953,
#               '台電大樓': 996,
#               '動物園': 1853,
#               '新莊': 650,
#               '土城': 1450,
#               '亞東醫院': 1150,
#               '西門': 699,
#               '文德': 1619,
#               '松江南京': 575,
#               '忠義': 1578,
#               '海山': 1318,
#               '三重': 231,
#               '中山': 434,
#               '台北101/世貿': 1347,
#               '十四張': 1917,
#               '中原': 1558,
#               '永春': 1260,
#               '昆陽': 1497,
#               '頂埔': 1779,
#               '西湖': 1432,
#               '淡水': 2194,
#               '龍山寺': 837,
#               '菜寮': 122,
#               '秀朗橋': 1830,
#               '芝山': 743,
#               '關渡': 1683,
#               '紅樹林': 2019,
#               '南京三民': 940,
#               '松山': 1078,
#               '後山埤': 1365,
#               '大直': 1169,
#               '內湖': 1722,
#               '景美': 1372,
#               '新埔': 1060,
#               '東湖': 1930,
#               '丹鳳': 950,
#               '三重國小': 328,
#               '新埔民生': 1013,
#               '中山國小': 355,
#               '北門': 585,
#               '南港': 1630,
#               '大湖公園': 1818,
#               '輔大': 812,
#               '大橋頭': 152,
#               '雙連': 344,
#               '松山機場': 972,
#               '板新': 1422,
#               '徐匯中學': 567,
#               '市政府': 1148,
#               '復興崗': 1441,
#               '善導寺': 621,
#               '麟光': 1285,
#               '中和': 1784,
#               '明德': 848,
#               '新店': 1837,
#               '府中': 1020,
#               '先嗇宮': 398,
#               '江子翠': 1058,
#               '三和國中': 460,
#               '國父紀念館': 1043,
#               '萬芳醫院': 1565,
#               '大安森林公園': 1001,
#               '幸福': 953,
#               '永安市場': 1488,
#               '石牌': 937,
#               '萬隆': 1256},
#              '頭前庄': {'中正紀念堂': 1319,
#               '象山': 2035,
#               '中山國中': 1711,
#               '辛亥': 2108,
#               '圓山': 930,
#               '新北產業園區': 253,
#               '竹圍': 2422,
#               '民權西路': 816,
#               '古亭': 1345,
#               '士林': 1189,
#               '東門': 1461,
#               '橋和': 820,
#               '港墘': 2428,
#               '台北橋': 870,
#               '頭前庄': 35,
#               '台大醫院': 1198,
#               '劍南路': 2203,
#               '六張犁': 1862,
#               '行天宮': 1047,
#               '南港展覽館': 2395,
#               '科技大樓': 1715,
#               '三民高中': 744,
#               '大安': 1616,
#               '台北車站': 1499,
#               '唭哩岸': 1630,
#               '頂溪': 1922,
#               '忠孝復興': 1549,
#               '劍潭': 1068,
#               '大坪林': 1903,
#               '永寧': 2913,
#               '忠孝新生': 1327,
#               '萬芳社區': 2363,
#               '蘆洲': 744,
#               '奇岩': 1728,
#               '信義安和': 1793,
#               '迴龍': 1988,
#               '葫洲': 2686,
#               '公館': 1572,
#               '北投': 1847,
#               '台北小巨蛋': 1391,
#               '七張': 1822,
#               '景平': 1287,
#               '南港軟體園區': 2473,
#               '南京復興': 1620,
#               '木柵': 2435,
#               '小南門': 1117,
#               '南勢角': 2298,
#               '忠孝敦化': 1510,
#               '景安': 2173,
#               '新店區公所': 1903,
#               '板橋': 2267,
#               '台電大樓': 1463,
#               '動物園': 2527,
#               '新莊': 1520,
#               '土城': 2792,
#               '亞東醫院': 2492,
#               '西門': 1034,
#               '文德': 2525,
#               '松江南京': 1190,
#               '忠義': 2144,
#               '海山': 2660,
#               '三重': 1101,
#               '中山': 1000,
#               '台北101/世貿': 1913,
#               '十四張': 1525,
#               '中原': 723,
#               '永春': 1826,
#               '昆陽': 2063,
#               '頂埔': 3121,
#               '西湖': 2338,
#               '淡水': 2760,
#               '龍山寺': 1806,
#               '菜寮': 992,
#               '秀朗橋': 1391,
#               '芝山': 1309,
#               '關渡': 2249,
#               '紅樹林': 2585,
#               '南京三民': 1520,
#               '松山': 1658,
#               '後山埤': 1931,
#               '大直': 2075,
#               '內湖': 2628,
#               '景美': 1839,
#               '新埔': 2132,
#               '東湖': 2583,
#               '丹鳳': 1820,
#               '三重國小': 744,
#               '新埔民生': 178,
#               '中山國小': 921,
#               '北門': 1114,
#               '南港': 2196,
#               '大湖公園': 2724,
#               '輔大': 1682,
#               '大橋頭': 744,
#               '雙連': 910,
#               '松山機場': 1878,
#               '板新': 587,
#               '徐匯中學': 744,
#               '市政府': 1714,
#               '復興崗': 2007,
#               '善導寺': 1408,
#               '麟光': 1959,
#               '中和': 949,
#               '明德': 1414,
#               '新店': 2039,
#               '府中': 2362,
#               '先嗇宮': 1268,
#               '江子翠': 2027,
#               '三和國中': 744,
#               '國父紀念館': 1609,
#               '萬芳醫院': 2239,
#               '大安森林公園': 1567,
#               '幸福': 118,
#               '永安市場': 2054,
#               '石牌': 1503,
#               '萬隆': 1723},
#              '台大醫院': {'中正紀念堂': 121,
#               '象山': 900,
#               '中山國中': 555,
#               '辛亥': 1048,
#               '圓山': 496,
#               '新北產業園區': 1416,
#               '竹圍': 1988,
#               '民權西路': 578,
#               '古亭': 600,
#               '士林': 755,
#               '東門': 487,
#               '橋和': 1296,
#               '港墘': 1272,
#               '台北橋': 632,
#               '頭前庄': 1198,
#               '台大醫院': 26,
#               '劍南路': 1047,
#               '六張犁': 802,
#               '行天宮': 447,
#               '南港展覽館': 1335,
#               '科技大樓': 655,
#               '三民高中': 506,
#               '大安': 556,
#               '台北車站': 503,
#               '唭哩岸': 1196,
#               '頂溪': 466,
#               '忠孝復興': 489,
#               '劍潭': 634,
#               '大坪林': 1069,
#               '永寧': 1593,
#               '忠孝新生': 540,
#               '萬芳社區': 1303,
#               '蘆洲': 506,
#               '奇岩': 1294,
#               '信義安和': 658,
#               '迴龍': 1750,
#               '葫洲': 1626,
#               '公館': 794,
#               '北投': 1413,
#               '台北小巨蛋': 868,
#               '七張': 988,
#               '景平': 1157,
#               '南港軟體園區': 1413,
#               '南京復興': 494,
#               '木柵': 1375,
#               '小南門': 381,
#               '南勢角': 842,
#               '忠孝敦化': 723,
#               '景安': 717,
#               '新店區公所': 1069,
#               '板橋': 947,
#               '台電大樓': 685,
#               '動物園': 1467,
#               '新莊': 1282,
#               '土城': 1472,
#               '亞東醫院': 1172,
#               '西門': 298,
#               '文德': 1369,
#               '松江南京': 667,
#               '忠義': 1710,
# ...
#               '市政府': 1895,
#               '復興崗': 2492,
#               '善導寺': 1347,
#               '麟光': 280,
#               '中和': 2400,
#               '明德': 1899,
#               '新店': 2117,
#               '府中': 2083,
#               '先嗇宮': 1963,
#               '江子翠': 1748,
#               '三和國中': 1413,
#               '國父紀念館': 1790,
#               '萬芳醫院': 25,
#               '大安森林公園': 1611,
#               '幸福': 2357,
#               '永安市場': 1421,
#               '石牌': 1988,
#               '萬隆': 1536},
#              '大安森林公園': {'中正紀念堂': 311,
#               '象山': 468,
#               '中山國中': 987,
#               '辛亥': 1480,
#               '圓山': 928,
#               '新北產業園區': 1785,
#               '竹圍': 2420,
#               '民權西路': 947,
#               '古亭': 380,
#               '士林': 1187,
#               '東門': 677,
#               '橋和': 1166,
#               '港墘': 1704,
#               '台北橋': 1001,
#               '頭前庄': 1567,
#               '台大醫院': 432,
#               '劍南路': 1479,
#               '六張犁': 1234,
#               '行天宮': 879,
#               '南港展覽館': 1767,
#               '科技大樓': 1087,
#               '三民高中': 875,
#               '大安': 988,
#               '台北車站': 492,
#               '唭哩岸': 1628,
#               '頂溪': 656,
#               '忠孝復興': 921,
#               '劍潭': 1066,
#               '大坪林': 960,
#               '永寧': 1783,
#               '忠孝新生': 320,
#               '萬芳社區': 1735,
#               '蘆洲': 875,
#               '奇岩': 1726,
#               '信義安和': 226,
#               '迴龍': 2119,
#               '葫洲': 2058,
#               '公館': 574,
#               '北投': 1845,
#               '台北小巨蛋': 438,
#               '七張': 1065,
#               '景平': 937,
#               '南港軟體園區': 1845,
#               '南京復興': 926,
#               '木柵': 1807,
#               '小南門': 575,
#               '南勢角': 1032,
#               '忠孝敦化': 304,
#               '景安': 907,
#               '新店區公所': 1170,
#               '板橋': 1137,
#               '台電大樓': 465,
#               '動物園': 1899,
#               '新莊': 1651,
#               '土城': 1662,
#               '亞東醫院': 1362,
#               '西門': 692,
#               '文德': 1801,
#               '松江南京': 447,
#               '忠義': 2142,
#               '海山': 1530,
#               '三重': 1232,
#               '中山': 630,
#               '台北101/世貿': 346,
#               '十四張': 1175,
#               '中原': 1263,
#               '永春': 620,
#               '昆陽': 857,
#               '頂埔': 1991,
#               '西湖': 1614,
#               '淡水': 2758,
#               '龍山寺': 676,
#               '菜寮': 1123,
#               '秀朗橋': 1041,
#               '芝山': 1307,
#               '關渡': 2247,
#               '紅樹林': 2583,
#               '南京三民': 567,
#               '松山': 705,
#               '後山埤': 725,
#               '大直': 1351,
#               '內湖': 1904,
#               '景美': 841,
#               '新埔': 1002,
#               '東湖': 1955,
#               '丹鳳': 1951,
#               '三重國小': 875,
#               '新埔民生': 1518,
#               '中山國小': 1005,
#               '北門': 704,
#               '南港': 990,
#               '大湖公園': 2000,
#               '輔大': 1813,
#               '大橋頭': 875,
#               '雙連': 720,
#               '松山機場': 1154,
#               '板新': 1399,
#               '徐匯中學': 875,
#               '市政府': 508,
#               '復興崗': 2005,
#               '善導寺': 401,
#               '麟光': 1331,
#               '中和': 1037,
#               '明德': 1412,
#               '新店': 1306,
#               '府中': 1232,
#               '先嗇宮': 1399,
#               '江子翠': 897,
#               '三和國中': 875,
#               '國父紀念館': 403,
#               '萬芳醫院': 1611,
#               '大安森林公園': 25,
#               '幸福': 1650,
#               '永安市場': 788,
#               '石牌': 1501,
#               '萬隆': 725},
#              '幸福': {'中正紀念堂': 1402,
#               '象山': 2118,
#               '中山國中': 1829,
#               '辛亥': 2226,
#               '圓山': 1013,
#               '新北產業園區': 135,
#               '竹圍': 2505,
#               '民權西路': 899,
#               '古亭': 1463,
#               '士林': 1272,
#               '東門': 1544,
#               '橋和': 938,
#               '港墘': 2546,
#               '台北橋': 953,
#               '頭前庄': 118,
#               '台大醫院': 1281,
#               '劍南路': 2321,
#               '六張犁': 1980,
#               '行天宮': 1130,
#               '南港展覽館': 2513,
#               '科技大樓': 1833,
#               '三民高中': 827,
#               '大安': 1734,
#               '台北車站': 1582,
#               '唭哩岸': 1713,
#               '頂溪': 2005,
#               '忠孝復興': 1667,
#               '劍潭': 1151,
#               '大坪林': 2021,
#               '永寧': 2996,
#               '忠孝新生': 1410,
#               '萬芳社區': 2481,
#               '蘆洲': 827,
#               '奇岩': 1811,
#               '信義安和': 1876,
#               '迴龍': 2071,
#               '葫洲': 2804,
#               '公館': 1690,
#               '北投': 1930,
#               '台北小巨蛋': 1474,
#               '七張': 1940,
#               '景平': 1405,
#               '南港軟體園區': 2591,
#               '南京復興': 1738,
#               '木柵': 2553,
#               '小南門': 1235,
#               '南勢角': 2381,
#               '忠孝敦化': 1593,
#               '景安': 2256,
#               '新店區公所': 2021,
#               '板橋': 2350,
#               '台電大樓': 1581,
#               '動物園': 2645,
#               '新莊': 1603,
#               '土城': 2875,
#               '亞東醫院': 2575,
#               '西門': 1152,
#               '文德': 2643,
#               '松江南京': 1273,
#               '忠義': 2227,
#               '海山': 2743,
#               '三重': 1184,
#               '中山': 1083,
#               '台北101/世貿': 1996,
#               '十四張': 1643,
#               '中原': 841,
#               '永春': 1909,
#               '昆陽': 2146,
#               '頂埔': 3204,
#               '西湖': 2456,
#               '淡水': 2843,
#               '龍山寺': 1889,
#               '菜寮': 1075,
#               '秀朗橋': 1509,
#               '芝山': 1392,
#               '關渡': 2332,
#               '紅樹林': 2668,
#               '南京三民': 1603,
#               '松山': 1741,
#               '後山埤': 2014,
#               '大直': 2193,
#               '內湖': 2746,
#               '景美': 1957,
#               '新埔': 2215,
#               '東湖': 2701,
#               '丹鳳': 1903,
#               '三重國小': 827,
#               '新埔民生': 296,
#               '中山國小': 1004,
#               '北門': 1232,
#               '南港': 2279,
#               '大湖公園': 2842,
#               '輔大': 1765,
#               '大橋頭': 827,
#               '雙連': 993,
#               '松山機場': 1996,
#               '板新': 705,
#               '徐匯中學': 827,
#               '市政府': 1797,
#               '復興崗': 2090,
#               '善導寺': 1491,
#               '麟光': 2077,
#               '中和': 1067,
#               '明德': 1497,
#               '新店': 2157,
#               '府中': 2445,
#               '先嗇宮': 1351,
#               '江子翠': 2110,
#               '三和國中': 827,
#               '國父紀念館': 1692,
#               '萬芳醫院': 2357,
#               '大安森林公園': 1650,
#               '幸福': 23,
#               '永安市場': 2137,
#               '石牌': 1586,
#               '萬隆': 1841},
#              '永安市場': {'中正紀念堂': 507,
#               '象山': 1256,
#               '中山國中': 1104,
#               '辛亥': 1290,
#               '圓山': 1094,
#               '新北產業園區': 2272,
#               '竹圍': 2586,
#               '民權西路': 1238,
#               '古亭': 923,
#               '士林': 1353,
#               '東門': 593,
#               '橋和': 1838,
#               '港墘': 1821,
#               '台北橋': 1488,
#               '頭前庄': 2054,
#               '台大醫院': 598,
#               '劍南路': 1596,
#               '六張犁': 1044,
#               '行天宮': 1007,
#               '南港展覽館': 1788,
#               '科技大樓': 897,
#               '三民高中': 1868,
#               '大安': 828,
#               '台北車站': 859,
#               '唭哩岸': 1794,
#               '頂溪': 132,
#               '忠孝復興': 910,
#               '劍潭': 1232,
#               '大坪林': 671,
#               '永寧': 1539,
#               '忠孝新生': 1071,
#               '萬芳社區': 1545,
#               '蘆洲': 1979,
#               '奇岩': 1892,
#               '信義安和': 1014,
#               '迴龍': 2606,
#               '葫洲': 2079,
#               '公館': 1030,
#               '北投': 2011,
#               '台北小巨蛋': 1494,
#               '七張': 749,
#               '景平': 1371,
#               '南港軟體園區': 1866,
#               '南京復興': 1013,
#               '木柵': 1617,
#               '小南門': 901,
#               '南勢角': 244,
#               '忠孝敦化': 1294,
#               '景安': 119,
#               '新店區公所': 854,
#               '板橋': 921,
#               '台電大樓': 1041,
#               '動物園': 1709,
#               '新莊': 2138,
#               '土城': 1418,
#               '亞東醫院': 1118,
#               '西門': 1018,
#               '文德': 1918,
#               '松江南京': 1258,
#               '忠義': 2308,
#               '海山': 1286,
#               '三重': 1719,
#               '中山': 796,
#               '台北101/世貿': 1134,
#               '十四張': 1133,
#               '中原': 1935,
#               '永春': 1610,
#               '昆陽': 1847,
#               '頂埔': 1747,
#               '西湖': 1731,
#               '淡水': 2924,
#               '龍山寺': 842,
#               '菜寮': 1610,
#               '秀朗橋': 1267,
#               '芝山': 1473,
#               '關渡': 2413,
#               '紅樹林': 2749,
#               '南京三民': 1623,
#               '松山': 1761,
#               '後山埤': 1715,
#               '大直': 1468,
#               '內湖': 2021,
#               '景美': 763,
#               '新埔': 1028,
#               '東湖': 1976,
#               '丹鳳': 2438,
#               '三重國小': 1512,
#               '新埔民生': 1963,
#               '中山國小': 1133,
#               '北門': 1132,
#               '南港': 1980,
#               '大湖公園': 2117,
#               '輔大': 2300,
#               '大橋頭': 1336,
#               '雙連': 886,
#               '松山機場': 1271,
#               '板新': 1940,
#               '徐匯中學': 1751,
#               '市政府': 1498,
#               '復興崗': 2171,
#               '善導寺': 950,
#               '麟光': 1141,
#               '中和': 1709,
#               '明德': 1578,
#               '新店': 990,
#               '府中': 988,
#               '先嗇宮': 1886,
#               '江子翠': 1063,
#               '三和國中': 1644,
#               '國父紀念館': 1393,
#               '萬芳醫院': 1421,
#               '大安森林公園': 788,
#               '幸福': 2137,
#               '永安市場': 29,
#               '石牌': 1667,
#               '萬隆': 879},
#              '石牌': {'中正紀念堂': 1190,
#               '象山': 1969,
#               '中山國中': 1228,
#               '辛亥': 1857,
#               '圓山': 573,
#               '新北產業園區': 1721,
#               '竹圍': 919,
#               '民權西路': 883,
#               '古亭': 1474,
#               '士林': 314,
#               '東門': 1318,
#               '橋和': 2161,
#               '港墘': 1945,
#               '台北橋': 937,
#               '頭前庄': 1503,
#               '台大醫院': 1069,
#               '劍南路': 1720,
#               '六張犁': 1611,
#               '行天宮': 1114,
#               '南港展覽館': 2200,
#               '科技大樓': 1464,
#               '三民高中': 811,
#               '大安': 1365,
#               '台北車站': 1298,
#               '唭哩岸': 127,
#               '頂溪': 1535,
#               '忠孝復興': 1253,
#               '劍潭': 435,
#               '大坪林': 2087,
#               '永寧': 2388,
#               '忠孝新生': 1198,
#               '萬芳社區': 2112,
#               '蘆洲': 811,
#               '奇岩': 225,
#               '信義安和': 1727,
#               '迴龍': 2055,
#               '葫洲': 2387,
#               '公館': 1701,
#               '北投': 344,
#               '台北小巨蛋': 1262,
#               '七張': 2057,
#               '景平': 2163,
#               '南港軟體園區': 2278,
#               '南京復興': 1167,
#               '木柵': 2184,
#               '小南門': 1246,
#               '南勢角': 1911,
#               '忠孝敦化': 1381,
#               '景安': 1786,
#               '新店區公所': 2138,
#               '板橋': 1742,
#               '台電大樓': 1592,
#               '動物園': 2276,
#               '新莊': 1587,
#               '土城': 2267,
#               '亞東醫院': 1967,
#               '西門': 1163,
#               '文德': 2042,
#               '松江南京': 1061,
#               '忠義': 641,
#               '海山': 2135,
#               '三重': 1168,
#               '中山': 871,
#               '台北101/世貿': 1847,
#               '十四張': 2096,
#               '中原': 2064,
#               '永春': 1697,
#               '昆陽': 1934,
#               '頂埔': 2596,
#               '西湖': 1855,
#               '淡水': 1257,
#               '龍山寺': 1281,
#               '菜寮': 1059,
#               '秀朗橋': 2230,
#               '芝山': 194,
#               '關渡': 746,
#               '紅樹林': 1082,
#               '南京三民': 1391,
#               '松山': 1529,
#               '後山埤': 1802,
#               '大直': 1592,
#               '內湖': 2145,
#               '景美': 1968,
#               '新埔': 1607,
#               '東湖': 2388,
#               '丹鳳': 1887,
#               '三重國小': 811,
#               '新埔民生': 1646,
#               '中山國小': 988,
#               '北門': 1243,
#               '南港': 2067,
#               '大湖公園': 2241,
#               '輔大': 1749,
#               '大橋頭': 811,
#               '雙連': 781,
#               '松山機場': 1395,
#               '板新': 1928,
#               '徐匯中學': 811,
#               '市政府': 1585,
#               '復興崗': 504,
#               '善導寺': 1279,
#               '麟光': 1708,
#               '中和': 2263,
#               '明德': 89,
#               '新店': 2274,
#               '府中': 1837,
#               '先嗇宮': 1335,
#               '江子翠': 1502,
#               '三和國中': 811,
#               '國父紀念館': 1480,
#               '萬芳醫院': 1988,
#               '大安森林公園': 1501,
#               '幸福': 1586,
#               '永安市場': 1667,
#               '石牌': 26,
#               '萬隆': 1852},
#              '萬隆': {'中正紀念堂': 824,
#               '象山': 1193,
#               '中山國中': 1232,
#               '辛亥': 1405,
#               '圓山': 1279,
#               '新北產業園區': 1976,
#               '竹圍': 2612,
#               '民權西路': 1039,
#               '古亭': 378,
#               '士林': 1538,
#               '東門': 741,
#               '橋和': 1197,
#               '港墘': 1949,
#               '台北橋': 1256,
#               '頭前庄': 1723,
#               '台大醫院': 945,
#               '劍南路': 1724,
#               '六張犁': 1159,
#               '行天宮': 1122,
#               '南港展覽館': 2118,
#               '科技大樓': 1012,
#               '三民高中': 1104,
#               '大安': 943,
#               '台北車站': 768,
#               '唭哩岸': 1979,
#               '頂溪': 1011,
#               '忠孝復興': 1025,
#               '劍潭': 1417,
#               '大坪林': 235,
#               '永寧': 2140,
#               '忠孝新生': 833,
#               '萬芳社區': 1660,
#               '蘆洲': 1104,
#               '奇岩': 2077,
#               '信義安和': 951,
#               '迴龍': 2374,
#               '葫洲': 2391,
#               '公館': 151,
#               '北投': 2065,
#               '台北小巨蛋': 1365,
#               '七張': 340,
#               '景平': 851,
#               '南港軟體園區': 2196,
#               '南京復興': 1141,
#               '木柵': 1732,
#               '小南門': 606,
#               '南勢角': 885,
#               '忠孝敦化': 1016,
#               '景安': 788,
#               '新店區公所': 445,
#               '板橋': 1494,
#               '台電大樓': 260,
#               '動物園': 1824,
#               '新莊': 1906,
#               '土城': 2019,
#               '亞東醫院': 1719,
#               '西門': 723,
#               '文德': 2046,
#               '松江南京': 1129,
#               '忠義': 2334,
#               '海山': 1887,
#               '三重': 1487,
#               '中山': 981,
#               '台北101/世貿': 1071,
#               '十四張': 613,
#               '中原': 1294,
#               '永春': 1332,
#               '昆陽': 1569,
#               '頂埔': 2348,
#               '西湖': 1859,
#               '淡水': 2950,
#               '龍山寺': 1033,
#               '菜寮': 1378,
#               '秀朗橋': 747,
#               '芝山': 1658,
#               '關渡': 2439,
#               '紅樹林': 2775,
#               '南京三民': 1494,
#               '松山': 1632,
#               '後山埤': 1437,
#               '大直': 1596,
#               '內湖': 2149,
#               '景美': 116,
#               '新埔': 1359,
#               '東湖': 2306,
#               '丹鳳': 2206,
#               '三重國小': 1104,
#               '新埔民生': 1545,
#               '中山國小': 1111,
#               '北門': 837,
#               '南港': 1702,
#               '大湖公園': 2245,
#               '輔大': 2068,
#               '大橋頭': 1104,
#               '雙連': 1071,
#               '松山機場': 1399,
#               '板新': 1430,
#               '徐匯中學': 1104,
#               '市政府': 1220,
#               '復興崗': 2197,
#               '善導寺': 817,
#               '麟光': 1256,
#               '中和': 1068,
#               '明德': 1763,
#               '新店': 581,
#               '府中': 1589,
#               '先嗇宮': 1654,
#               '江子翠': 1254,
#               '三和國中': 1104,
#               '國父紀念館': 1115,
#               '萬芳醫院': 1536,
#               '大安森林公園': 725,
#               '幸福': 1841,
#               '永安市場': 879,
#               '石牌': 1852,
#               '萬隆': 27}})

# %%
all_time["中正紀念堂"]["象山"]
# Out:
# 779

# %%
import pickle
with open('all_time.pickle', 'wb') as handle:
    pickle.dump(all_time, handle)
    handle.close()
